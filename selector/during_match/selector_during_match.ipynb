# %%
# !pip install --quiet transformers evaluate datasets baal
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 52.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 7.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.2/486.2 kB 49.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 29.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 109.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 45.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 12.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 19.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 15.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 60.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 5.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.6/419.6 kB 34.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 11.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 31.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 21.1 MB/s eta 0:00:00

# %%
# !pip install --quiet --upgrade accelerate
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.6/227.6 kB 8.9 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp "/content/drive/MyDrive/RuSportSum/train_selector_during_match2.csv" /content/train.csv
# !cp "/content/drive/MyDrive/RuSportSum/eval_selector_during_match2.csv" /content/eval.csv

# %%
train = pd.read_csv("/content/train.csv")
eval = pd.read_csv("/content/eval.csv")

data = pd.concat([train, eval])
data['len_content'] = data['content'].apply(lambda x: len(str(x).split()))
data['len_news_name_body'] = data['news_name_body'].apply(lambda x: len(str(x).split()))
data[['len_content', 'len_news_name_body']].describe()
# Out:
#          len_content  len_news_name_body
# count  336724.000000       336724.000000
# mean       18.095235           65.717089
# std        10.897307           20.117228
# min         2.000000           25.000000
# 25%        11.000000           52.000000
# 50%        16.000000           62.000000
# 75%        23.000000           75.000000
# max       151.000000          313.000000

# %%
train['relevant_part'].value_counts()
# Out:
# 0    327805
# 1       667
# Name: relevant_part, dtype: int64

# %%
temp = train.iloc[:21_015]
indexes = temp[temp['relevant_part'] == 0].index.to_list()
print(len(indexes))
train.drop(random.sample(indexes, k=17_000), inplace=True)
# Out:
# 20348

# %%
train.iloc[:30_000].to_csv('train.csv', index=False, encoding='utf-8')
eval.to_csv('eval.csv', index=False, encoding='utf-8')

# %% [markdown]
# #### Разметка релевантных новостей с активным обучением

# %%
import os
import random
import pandas as pd
from copy import deepcopy

import numpy as np
import torch.backends
import transformers
import evaluate

from datasets import load_dataset
from tqdm import tqdm
from transformers import BertForSequenceClassification
from transformers import BertTokenizer, TrainingArguments
from transformers import set_seed

from transformers import (
    AutoConfig,
    AutoModelForSequenceClassification,
    AutoTokenizer,
    DataCollatorWithPadding,
    PretrainedConfig,
    set_seed,
    Trainer,
    TrainingArguments
)

transformers.utils.logging.set_verbosity_warning()

from baal.active import get_heuristic
from baal.active.dataset.nlp_datasets import (
    active_huggingface_dataset,
    HuggingFaceDatasets,
)
from baal.bayesian.dropout import patch_module
from baal.transformers_trainer_wrapper import BaalTransformersTrainer
from baal.active import get_heuristic, ActiveLearningDataset
from baal.active.dataset.base import Dataset

from typing import List
from pprint import pprint

SEED = 3

random.seed(SEED)
torch.manual_seed(SEED)

# Set tranformer seed to ensure that initial weights are identical
set_seed(SEED)

# %%
class CustomHuggingFaceDatasets(Dataset):
    """
    Support for `huggingface.datasets`: (https://github.com/huggingface/datasets).
    The purpose of this wrapper is to separate the labels from the rest of the sample information
    and make the dataset ready to be used by `baal.active.ActiveLearningDataset`.
    Args:
        dataset (Dataset): a dataset provided by huggingface.
        tokenizer (transformers.PreTrainedTokenizer): a tokenizer provided by huggingface.
        target_key (str): target key used in the dataset's dictionary.
        input_key (str): input key used in the dataset's dictionary.
        max_seq_len (int): max length of a sequence to be used for padding the shorter
            sequences.
    """

    def __init__(
        self,
        dataset,
        tokenizer=None,
        target_key: str = "label",
        input_key_1: str = "sentence1",
        input_key_2: str = "sentence1",
        max_seq_len: int = 200,
    ):
        self.dataset = dataset
        self.targets, self.text1, self.text2 = self.dataset[target_key], self.dataset[input_key_1], self.dataset[input_key_2]
        self.targets_list: List = np.unique(self.targets).tolist()
        self.input_ids, self.attention_masks = (
            self._tokenize(tokenizer, max_seq_len) if tokenizer else ([], [])
        )

    @property
    def num_classes(self):
        return len(self.targets_list)

    def _tokenize(self, tokenizer, max_seq_len):
        # For speed purposes, we should use fast tokenizers here, but that is up to the caller
        tokenized = tokenizer(
            self.text1,
            self.text2,
            add_special_tokens=True,
            max_length=max_seq_len,
            return_token_type_ids=False,
            padding="max_length",
            return_attention_mask=True,
            return_tensors="pt",
            truncation=True,
        )
        return tokenized["input_ids"], tokenized["attention_mask"]

    def label(self, idx: int, value: int):
        """Label the item.
        Args:
            idx: index to label
            value: Value to label the index.
        """
        self.targets[idx] = value

    def __len__(self):
        return len(self.text1)

    def __getitem__(self, idx):
        target = self.targets_list.index(self.targets[idx])

        return {
            "input_ids": self.input_ids[idx].flatten() if len(self.input_ids) > 0 else None,
            "inputs": self.text1[idx] + '\n' + self.text2[idx],
            "attention_mask": self.attention_masks[idx].flatten()
            if len(self.attention_masks) > 0
            else None,
            "label": torch.tensor(target, dtype=torch.long),
        }

def custom_active_huggingface_dataset(
    dataset,
    tokenizer=None,
    target_key: str = "label",
    input_key_1: str = "sentence1",
    input_key_2: str = "sentence2",
    max_seq_len: int = 200,
    **kwargs
):
    """
    Wrapping huggingface.datasets with baal.active.ActiveLearningDataset.
    Args:
        dataset (torch.utils.data.Dataset): a dataset provided by huggingface.
        tokenizer (transformers.PreTrainedTokenizer): a tokenizer provided by huggingface.
        target_key (str): target key used in the dataset's dictionary.
        input_key (str): input key used in the dataset's dictionary.
        max_seq_len (int): max length of a sequence to be used for padding the shorter sequences.
        kwargs (Dict): Parameters forwarded to 'ActiveLearningDataset'.
    Returns:
        an baal.active.ActiveLearningDataset object.
    """

    return ActiveLearningDataset(
        CustomHuggingFaceDatasets(dataset, tokenizer, target_key, input_key_1, input_key_2, max_seq_len), **kwargs
    )

# %% [markdown]
# Information on the hyperparms below
#
# * epoch: Number of times you want to run and AL loop
# * batch_size: The train and eval batch size for hf trainer arguments
# * model: Hugging Face Model
# * query_size: Number of samples you want to query at each AL iteration for labelling
# * heuristic: The acquisition function/heuristic based on which you want to query the important samples
# * iterations: The number of iterations you want to run for MCdropout to find the uncertanities
# * shuffle_prop: Additional Noise to counter selection bias
# * learning_epoch: Traing epochs for hugging face trainer

# %%
hyperparams = {
    "epoch": 4,
    "batch_size": 40,
    "model": "DeepPavlov/rubert-base-cased",
    "query_size": 50,
    "heuristic": "bald",
    "iterations": 10,
    "shuffle_prop": 0.05,
    "learning_epoch": 2,
}

# %%
# Check for CUDA
use_cuda = torch.cuda.is_available()
torch.backends.cudnn.benchmark = True

id2label = {0: "LABEL_0", 1: "LABEL_1"}
label2id = {"LABEL_0": 0, "LABEL_1": 1}

# Load Model
hf_model = AutoModelForSequenceClassification.from_pretrained(
    hyperparams["model"], num_labels=2, id2label=id2label, label2id=label2id
    )

# Setup tokenizer for model
tokenizer = AutoTokenizer.from_pretrained(hyperparams["model"])

# Enable dropouts for predictions
hf_model = patch_module(hf_model)

# Send model to device and setup cuda arguments
if use_cuda:
    hf_model.to("cuda:0")
    no_cuda = False
else:
    hf_model.to("cpu")
    no_cuda = True
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/642 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Some weights of the model checkpoint at DeepPavlov/rubert-base-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at DeepPavlov/rubert-base-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading (…)okenizer_config.json:   0%|          | 0.00/24.0 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt: 0.00B [00:00, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
# Define labels in your dataset
label_list = [0, 1]

# Load data from files
data = load_dataset("csv", data_files={'train': '/content/train.csv', 'eval': "/content/eval.csv"})
# Out:
# Downloading and preparing dataset csv/default to /root/.cache/huggingface/datasets/csv/default-70941af215d1140e/0.0.0/eea64c71ca8b46dd3f537ed218fc9bf495d5707789152eb2764f5c78fa66d59d...
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating eval split: 0 examples [00:00, ? examples/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-70941af215d1140e/0.0.0/eea64c71ca8b46dd3f537ed218fc9bf495d5707789152eb2764f5c78fa66d59d. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
def get_label_from_data(active_dataset, data, target, input1, input2, indexes) -> List[int]:
    """
    Get labels from the active dataset, this assumes that you have
    already labelled some samples in your initial dataset

    Args:
    ----
    active_dataset : Active dataset which consists of train and pool

    indexes : Indexes of the points for which labels are to be fetched
    from the data

    Returns:
    ----
    labels: Returns the corresponding labels

    """

    labels = []

    # Now since you labelled points earlier now some part of pool has become train
    # so in order to get the pool indexes based on your 'original' data i.e
    # your raw_train_set. Make sure to user __pool_tp

    raw_data_idx = active_dataset._pool_to_oracle_index(indexes)

    for idx in raw_data_idx:
        #print(f"Adding labels for Raw data Index {idx} : {data[input1][idx]}")
        #print(f"Adding labels for Raw data Index {idx} : {data[input2][idx]}")

        label = data[target][idx]
        labels.append(label)
        #print(label)
        #print("\n")

    return labels

# %%
def get_label_human_oracle(active_dataset, indexes) -> List[int]:
    """
    Get labels from human oracle. During the AL loop some samples
    will go to the human labeller

    Args:
    ----
    active_dataset : Active dataset which consists of train and pool

    indexes : Indexes of the points for which labels are to be fetched
    from the data

    Returns:
    ----
    labels: Returns the corresponding labels

    """
    # List for corresponding labels
    labels = []

    skipped = []

    for sample_idx, idx in enumerate(indexes):

        while True:
            try:
                print(idx)
                pprint(active_dataset.pool.__getitem__(idx)['inputs'], width=150)
                label = int(input())
            except ValueError:
                print("Sorry, I didn't understand that.")
                continue
            if label != -1 and label not in label_list:
                print(f"Allowed labels are {label_list}")
                continue
            if label == -1:
                print("Skipping this sample")
                skipped.append(sample_idx)
                break
            else:
                labels.append(label)
                break
        print("\n")

    indexes_upd = np.delete(indexes, skipped)

    return labels, indexes_upd

# %%
#small_data = data['train'].select(range(10_000))
small_data = data['train']

active_set = custom_active_huggingface_dataset(
    small_data,
    tokenizer=tokenizer,
    target_key='relevant_part',
    input_key_1='content',
    input_key_2='news_name_body'
)

active_set.can_label = True

# 700 первых объектов набора данных
label_from_data = get_label_from_data(active_set, small_data, 'relevant_part', 'content', 'news_name_body', range(4_015))

active_set.label(
    range(4_015),
    label_from_data,
)

valid_set = CustomHuggingFaceDatasets(data['eval'], tokenizer=tokenizer, target_key='relevant_part', input_key_1='content', input_key_2='news_name_body')

active_set, test_set = active_set, valid_set

# %%
# Setup Heuristics
heuristic = get_heuristic(
    hyperparams["heuristic"], hyperparams["shuffle_prop"]
)

# Model save checkpoint
save_checkpoint = 2

metric = evaluate.load("f1")

def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    predictions = np.argmax(predictions, axis=1)
    return metric.compute(predictions=predictions, references=labels)

# Keep track of initial model weights
init_weights = deepcopy(hf_model.state_dict())

training_args = TrainingArguments(
    output_dir=".",
    num_train_epochs=hyperparams["learning_epoch"],
    per_device_train_batch_size=hyperparams["batch_size"],
    per_device_eval_batch_size=hyperparams["batch_size"],
    weight_decay=0.01,
    logging_steps=10,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True
)

# Active Learning Trainer Wrapper
baal_trainer = BaalTransformersTrainer(
    model=hf_model,
    args=training_args,
    train_dataset=active_set,
    eval_dataset=test_set,
    tokenizer=None,
    compute_metrics=compute_metrics
)
# Out:
# Downloading builder script: 0.00B [00:00, ?B/s]

# %%
logs = []
last_epoch = hyperparams["epoch"] - 1

for epoch in tqdm(range(hyperparams["epoch"])):
    # we use the default setup of HuggingFace for training (ex: epoch=1).
    # The setup is adjustable when BaalHuggingFaceTrainer is defined.
    baal_trainer.train()
    print("\n")

    # Validation!
    #eval_metrics = baal_trainer.evaluate()
    #print("\n")

    if (epoch != last_epoch):
      # MCdropout to gather uncertanities
      predictions = baal_trainer.predict_on_dataset(
          active_set.pool, iterations=hyperparams["iterations"]
      )
      print("\n")

      # Acquistion of the most informative and diverse samples based on BatchBALD
      top_uncertainty = heuristic(predictions)[: hyperparams.get("query_size", 1)]

      # Send the samples for labelling from human oracle
      label_from_oracle, points_to_label_oracle = get_label_human_oracle(
          active_set, top_uncertainty
      )

      # Label active dataset
      active_set.label(points_to_label_oracle, label_from_oracle)

      # We reset the model weights to relearn from the new trainset.
      baal_trainer.load_state_dict(init_weights)
      baal_trainer.lr_scheduler = None

      active_logs = {
          "epoch": epoch,
          "labeled_data": active_set.labelled_map,
          "Next Training set size": len(active_set),
      }
      logs.append({**active_logs})
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#     <div>
#
#       <progress value='202' max='202' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [202/202 09:52, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.295000</td>
#       <td>0.093845</td>
#       <td>0.460759</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.140500</td>
#       <td>0.098544</td>
#       <td>0.578652</td>
#     </tr>
#   </tbody>
# </table><p>
# [282-MainThread  ] [baal.transformers_trainer_wrapper:predict_on_dataset_generator:67] 2023-06-25T12:33:25.248276Z [info     ] Start Predict                  dataset=25985
#   0%|          | 0/650 [00:00<?, ?it/s]
#   0%|          | 1/650 [00:04<52:33,  4.86s/it]
#   0%|          | 2/650 [00:09<51:58,  4.81s/it]
#   0%|          | 3/650 [00:14<52:07,  4.83s/it]
#   1%|          | 4/650 [00:19<52:41,  4.89s/it]
#   1%|          | 5/650 [00:24<53:16,  4.96s/it]
#   1%|          | 6/650 [00:29<53:54,  5.02s/it]
#   1%|          | 7/650 [00:34<54:17,  5.07s/it]
#   1%|          | 8/650 [00:39<54:15,  5.07s/it]
#   1%|▏         | 9/650 [00:44<53:49,  5.04s/it]
#   2%|▏         | 10/650 [00:49<53:13,  4.99s/it]
#   2%|▏         | 11/650 [00:54<52:41,  4.95s/it]
#   2%|▏         | 12/650 [00:59<52:06,  4.90s/it]
#   2%|▏         | 13/650 [01:04<51:34,  4.86s/it]
#   2%|▏         | 14/650 [01:08<51:07,  4.82s/it]
#   2%|▏         | 15/650 [01:13<50:44,  4.79s/it]
#   2%|▏         | 16/650 [01:18<50:26,  4.77s/it]
#   3%|▎         | 17/650 [01:23<50:19,  4.77s/it]
#   3%|▎         | 18/650 [01:27<50:17,  4.77s/it]
#   3%|▎         | 19/650 [01:32<50:15,  4.78s/it]
#   3%|▎         | 20/650 [01:37<50:17,  4.79s/it]
#   3%|▎         | 21/650 [01:42<50:24,  4.81s/it]
#   3%|▎         | 22/650 [01:47<50:31,  4.83s/it]
#  96%|█████████▌| 623/650 [50:23<02:11,  4.86s/it]
#  96%|█████████▌| 624/650 [50:27<02:06,  4.86s/it]
#  96%|█████████▌| 625/650 [50:32<02:01,  4.86s/it]
#  96%|█████████▋| 626/650 [50:37<01:56,  4.86s/it]
#  96%|█████████▋| 627/650 [50:42<01:51,  4.86s/it]
#  97%|█████████▋| 628/650 [50:47<01:46,  4.86s/it]
#  97%|█████████▋| 629/650 [50:52<01:42,  4.86s/it]
#  97%|█████████▋| 630/650 [50:57<01:37,  4.86s/it]
#  97%|█████████▋| 631/650 [51:02<01:32,  4.86s/it]
#  97%|█████████▋| 632/650 [51:06<01:27,  4.87s/it]
#  97%|█████████▋| 633/650 [51:11<01:22,  4.87s/it]
#  98%|█████████▊| 634/650 [51:16<01:17,  4.87s/it]
#  98%|█████████▊| 635/650 [51:21<01:12,  4.86s/it]
#  98%|█████████▊| 636/650 [51:26<01:08,  4.86s/it]
#  98%|█████████▊| 637/650 [51:31<01:03,  4.86s/it]
#  98%|█████████▊| 638/650 [51:36<00:58,  4.86s/it]
#  98%|█████████▊| 639/650 [51:40<00:53,  4.86s/it]
#  98%|█████████▊| 640/650 [51:45<00:48,  4.86s/it]
#  99%|█████████▊| 641/650 [51:50<00:43,  4.86s/it]
#  99%|█████████▉| 642/650 [51:55<00:38,  4.86s/it]
#  99%|█████████▉| 643/650 [52:00<00:34,  4.86s/it]
#  99%|█████████▉| 644/650 [52:05<00:29,  4.86s/it]
#  99%|█████████▉| 645/650 [52:10<00:24,  4.86s/it]
#  99%|█████████▉| 646/650 [52:14<00:19,  4.86s/it]
# 100%|█████████▉| 647/650 [52:19<00:14,  4.87s/it]
# 100%|█████████▉| 648/650 [52:24<00:09,  4.86s/it]
# 100%|█████████▉| 649/650 [52:29<00:04,  4.86s/it]
# 100%|██████████| 650/650 [52:32<00:00,  4.85s/it]
# 9351
# ('0 минута. Всем привет. Еврокубковый календарь этого года сверстан таким образом, что нетрудно и спутать, где тут Лига Чемпионов, а где Лига '
#  'Европы. Особенно, когда играют "Манчестер Сити" и "Порту".\n'
#  'Отаменди получил травму глаза & Защитник «Порту» Николас Отаменди получил повреждение глаза на 61-й минуте матча 1/16 финала Лиги Европы против '
#  '«Манчестер Сити». Защитник «драконов» Майкон Перейра Роке выбивал мяч и случайно попал своему коллеге по амплуа в глаз. Две минуты спустя главный '
#  'тренер «Порту» Витор Перейра заменил Отаменди на Кристиана Сэпунару. «Манчестер Сити» – «Порту». Онлайн')
# 0
#
#
# 15060
# ('0 минута. Привет! Вот и бразильцев уж нет, а Гана еще тут! А вместе с ней Уругвай.\n'
#  'Фусиле не сыграет в полуфинале с Голландией & Защитник «Порту» и сборной Уругвая в четвертьфинале чемпионата мира с Ганой на 20-й минуте получил '
#  'желтую карточку, которая стала для него второй на турнире. Если уругвайцам удастся выйти в полуфинал, Фусиле не сможет принять участие в этой игре '
#  'из-за дисквалификации. Напомним, что соперником победителя матча Уругвай – Гана в полуфинале будет сборная Голландии. Статистику выступлений '
#  'Фусиле на ЧМ-2010 смотрите здесь . Текстовую трансляцию матча Гана Уругвай можно увидеть здесь .')
# 0
#
#
# 1320
# ('0 минута. Итак, еще раз всем привет! голандцы спели нечто отличное от слов Михалкова, а испанцы и вовсе промолчали всю свою национальную мелодию.\n'
#  'Торрес получил травму в игре с Голландией & Нападающий сборной Испании Фернандо Торрес получил повреждение на последней минуте финального матча '
#  'ЧМ-2010. Игрок, пролежав полминуты на газоне, попросил помощи врачей. Sports.ru вел текстовую трансляцию финала ЧМ-2010.')
# 0
#
#
# 25948
# ('9 минута. Гаджиев готовится выйти на поле.\n'
#  'Джуджак получил травму в матче с «Ростовом» & Полузащитник «Анжи» Балаж Джуджак получил травму в матче 22-го тура премьер-лиги с «Ростовом» . При '
#  'розыгрыше углового венгр в воздухе столкнулся с игроком «Ростова» и, по всей видимости, повредил плечо. Его унесли с поля на носилках. Вместо '
#  'Джуджака вышел Махач Гаджиев . Статистику и текстовую трансляцию матча вы можете посмотреть здесь .')
# 1
#
#
# 13744
# ('0 минута. Итак, еще раз всем привет! голандцы спели нечто отличное от слов Михалкова, а испанцы и вовсе промолчали всю свою национальную мелодию.\n'
#  'Испанцы чаще били по воротам в основное время финального матча, голландцы – в створ & Статистика основного времени финального матча Голландия '
#  'Испания не дает однозначной картины о превосходстве той или иной команды. Сборная Испании больше владела мячом (58% на 42%) и чаще била по воротам '
#  '(12:8), голландцы чаще били в створ (5:2). Угловых команды подали поровну по 5. Фолов больше у сборной Голландии 22:14. Чаще всего фолил ван '
#  'Боммел 5. Чаще всего фолили на Иньесте и Рамосе по 5 раз. Более подробные данные, обновляемые в режиме онлайн, смотрите на странице статистики '
#  'матча .')
# 0
#
#
# 6122
# ('8 минута. КАЛАШНИКОВ! Дринчич мягко положил мяч на голову своего боевого товарища, который не смог попасть в створ из вратарской площади.\n'
#  'Жан Карлос сломал ногу в матче против «Рубина» & Бразильский нападающий «Амкара» Жан Карлос получил серьезную травму в первом тайме матча 9-го '
#  'тура чемпионата России с «Рубином». Футболист сломал малую берцовую кость, сообщает «НТВ-Плюс». Ожидается, что бразилец пропустит около двух '
#  'месяцев.')
# 0
#
#
# 25811
# ('0 минута. Привет всем, кто не представляет своей жизни без хоккея!\n'
#  '«Ак Барс» – ЦСКА. Прохоркин подрался с Обуховым & В концовке первого периода матча «Ак Барс» – ЦСКА произошла драка между форвардами хозяев '
#  'Дмитрием Обуховым и гостей Николаем Прохоркиным. В итоге оба игрока были наказаны пятиминутными штрафами, а Обухов – еще и малым штрафом за грубую '
#  'игру. Со статистикой Обухова можно ознакомиться здесь , а Прохоркина – здесь .')
# 0
#
#
# 10441
# ('1 минута. nan\n'
#  'Ким Нам Иль получил травму в матче с «Амкаром» & Опорный полузащитник «Томи» Ким Нам Иль получил травму в матче 22-го тура чемпионата России с '
#  '«Амкаром». Игрок упал после столкновения с хавбеком пермской команды Александром Коломейцевым в начале встречи, после чего был заменен на Никиту '
#  'Баженова. Текстовый онлайн матча читайте здесь .')
# 0
#
#
# 3576
# ("20 минута. гол! Дзюбо'оооо. Данни одним пасом расчленил всю самарскую оборону, Дзюба выскочил на вратаря и пробил мимо опорной ноги Лории. Чисто, "
#  '0:1.\n'
#  'Дзюба — в шаге от «Клуба 100» & Нападающий «Зенита» Артем Дзюба открыл счет в матче 21-го тура чемпионата России против «Крыльев Советов» – 1:0. '
#  'Для 27-летнего форварда этот мяч стал 10-м в этом сезоне и 99-м в зачете «Клуба 100».')
# 1
#
#
# 10262
# ('0 минута. Привет всем, кто не представляет своей жизни без хоккея!\n'
#  'Чернквист получил травму в игре с «Авангардом» & Защитник «Локомотива» Даниэль Чернквист получил повреждение в игре с «Авангардом» после '
#  'столкновения с Денисом Куляшом. Шведский хоккеист не смог подняться самостоятельно и покинул лед на носилках. Куляш получил 5 минут штрафа за '
#  'атаку сзади и был удален до конца игры. Текстовую трансляцию матча можно посмотреть здесь .')
# 0
#
#
# 14515
# ('82 минута. А Виллаш-Боаш через переводчика что-то объясняет Долгову, который уже переоделся.\n'
#  '«Уфа» – «Зенит». Данни забил в третьем матче подряд после выхода на замену & Полузащитник «Зенита» Данни отличился в матче 4-го тура чемпионата '
#  'России с «Уфой» (1:0). Для португальца этот мяч стал третьим в нынешнем сезоне. При этом все свои голы Данни забил во вторых таймах, выходя на '
#  'замену. Sports.ru проводил текстовую онлайн-трансляцию матча . Видео: Данни как самый эффективный футболист сезона')
# 0
#
#
# 418
# ('0 минута. Привет всем, кто не представляет своей жизни без хоккея!\n'
#  'СКА – «Салават Юлаев». Тарасенко забросил первую шайбу в сезоне & Нападающий СКА Владимир Тарасенко в матче с «Салаватом Юлаевым» забросил первую '
#  'шайбу в сезоне. 20-летний форвард отличился в третьем периоде, сделав счет 7:2 в пользу питерцев. Добавим, что эта игра стала для Тарасенко первой '
#  'в сезоне. Подробную статистику его игры смотрите здесь . ВИДЕО СКА – «Салават Юлаев». Онлайн')
# 0
#
#
# 13951
# ('1 минута. ПОНЕСЛАСЬ!\n'
#  'НХЛ. Кросби доставлен в больницу & Капитан «Питтсбурга» Сидни Кросби был доставлен в больницу во время матча регулярного чемпионата НХЛ против '
#  '«Айлендерс», информирует TSN. Напомним, что в первом периоде встречи шайба срикошетила в лицо нападающему сборной Канады, и он был вынужден '
#  'покинуть лед. Кросби не примет участия в этой игре. Подробную статистику выступлений Кросби вы можете посмотреть здесь .')
# 0
#
#
# 14572
# ('41 минута. \n'
#  'Ван Гал после 21-го тура в АПЛ набрал 37 очков, как и Мойес год назад & «Манчестер Юнайтед» на своем поле уступил «Саутгемптону» в матче 21-го '
#  'тура чемпионата Англии. Таким образом, команда Луи ван Гала, набрав 37 очков, осталась на четвертом месте. Отметим, что год назад при Дэвиде '
#  'Мойесе на этом отрезке сезона «МЮ» набрал те же 37 очков. Напомним, что Мойес был уволен в конце сезона, а сейчас он тренирует «Реал Сосьедад». '
#  'Sports.ru проводил онлайн-трансляцию этого матча .')
# 0
#
#
# 23605
# ('45 минута. Перерыв! Мне кажется, или у "Томи" большие проблемы?\n'
#  'Защитник «Томи» Строев получил травму в матче со «Спартаком» & Защитник «Томи» Виктор Строев получил травму в матче 23-го тура премьер-лиги со '
#  '«Спартаком». 22-летний игрок повредил ногу в столкновении с форвардом красно-белых Павлом Яковлевым. На 40-й минуте игры Строев был заменен на '
#  'нападающего Владимира Дядюна. Покинуть поле игрок смог только на машине медпомощи. За ходом этой игры вы можете следить с помощью текстовой '
#  'онлайн-трансляции Sports.ru.')
# 0
#
#
# 14616
# ('84 минута. \n'
#  'Ван Гал после 21-го тура в АПЛ набрал 37 очков, как и Мойес год назад & «Манчестер Юнайтед» на своем поле уступил «Саутгемптону» в матче 21-го '
#  'тура чемпионата Англии. Таким образом, команда Луи ван Гала, набрав 37 очков, осталась на четвертом месте. Отметим, что год назад при Дэвиде '
#  'Мойесе на этом отрезке сезона «МЮ» набрал те же 37 очков. Напомним, что Мойес был уволен в конце сезона, а сейчас он тренирует «Реал Сосьедад». '
#  'Sports.ru проводил онлайн-трансляцию этого матча .')
# 0
#
#
# 4719
# ('21 минута. Упс! Удаление у ЦСКА! Мамин отбывает нарушение за задержку при выходе на площадку. 4-на-4 играем!\n'
#  'СКА – ЦСКА. Гости получили удаление за поздний выход из раздевалки & Хоккеисты ЦСКА поздно вышли из раздевалки перед стартом второго периода матча '
#  'против СКА (0:3, второй период) и получили за это удаление. Штраф за задержку игры отправился отбывать Максим Мамин.')
# 1
#
#
# 17712
# ('0 минута. Привет всем, кто не представляет своей жизни без хоккея!\n'
#  'Нападающий сборной Швейцарии Мозер получил травму в матче с Канадой & Нападающий сборной Швейцарии Симон Мозер получил травму в матче с Канадой. '
#  'Во втором периоде он столкнулся с защитником «кленовых листьев» Дионом Фанюфом, после чего ударился головой об лед. Добавшись до скамейки, Мозер '
#  'потерял сознание, однако вскоре пришел в себя. На льду тут же появились носилки, но игрок сумел самостоятельно проследовать в раздевалку команды. '
#  'Sports.ru ведет текстовую трансляцию матча Канада – Швейцария. ВИДЕО')
# 0
#
#
# 5325
# ('23 минута. гол!!!! Архипов - 2:0! 1-й гол в плей-офф!\n'
#  '«Ак Барс» – «Салават Юлаев». Гончаров удален до конца матча & Защитник «Салавата Юлаева» Максим Гончаров был удален до конца матча в матче Кубка '
#  'Гагарина с «Ак Барсом» . 26-летний россиянин получил 2 минуты за толчок на борт и дисциплинарный штраф до конца игры. Напомним, что Sports.ru '
#  'проводит онлайн-трансляцию матча «Ак Барс» – «Салават Юлаев» .')
# 0
#
#
# 15935
# ('1 минута. ПОНЕСЛАСЬ! Звено Бигла начинает у хозяев, звено Певерли - у гостей. Бержерон, кстати, вполне себе здоров и играет.\n'
#  'НХЛ. Семин забил в третьем матче подряд & Форвард «Вашингтона» Александр Семин, отличившись в пятом матче первого раунда Кубка Стэнли с '
#  '«Бостоном», забил в третьей игре подряд. Это также третье очко россиянина в текущем плей-офф. Всего за карьеру он набрал 33 (15+18) очка в 42 '
#  'кубковых матчах. Подробную статистику Семина можно посмотреть здесь . «Бостон» – «Вашингтон». Онлайн')
# 0
#
#
# 1870
# ('20 минута. ЭШТОН!!!! 2:0! Проспект "Тампы" создал себе этот гол почти в одиночку. Долго возил шайбу за нашими воротами, легко обыгрывая, по ходу, '
#  'наших игроков, получил возврат от Леблана, и с правого острого угла бросил в ближнюю паутинку Шикина! И защита наша смотрелась гуттаперчиво, и '
#  'Шикин не выручил.\n'
#  'Тарасенко получил повреждение в матче с Канадой & Капитан молодежной сборной России Владимир Тарасенко в финальном матче МЧМ-2011 против Канады '
#  'получил повреждение. Инцидент произошел на 16-й минуте второго периода, когда при падении 19-летний россиянин получил удар ногой по голове со '
#  'стороны форварда канадцев Маркуса Фолиньо. После этого эпизода Тарасенко ушел в раздевалку в сопровождении медицинского персонала сборной. До '
#  'конца второго периода на льду он больше не появлялся. В третьей 20-минутке нападающий смог продолжить игру. Текстовый онлайн матча Канада Россия '
#  'смотрите здесь .')
# 0
#
#
# 19748
# ('0 минута. Привет всем, кто не представляет своей жизни без хоккея!\n'
#  'Арбитры отменили гол СКА в овертайме матча с «Динамо» & Арбитры первого матча полуфинала плей-офф КХЛ СКА – «Динамо» Роман Гофман и Анатолий '
#  'Захаров не засчитали гол армейца Тони Мортенссона в овертайме встречи. После видеопросмотра в офисе КХЛ было принято решение, что швед переправил '
#  'шайбу в ворота, умышленно задев ее ногой. Через несколько секунд бело-голубые забили победный гол – его автором стал Денис Мосалев . СКА проиграл '
#  '«Динамо». Как это было')
# 0
#
#
# 8720
# ('6 минута. ПЛАТОНОВ - 1:0!!! 3-й гол в сезоне!\n'
#  'Малкин забросил первую шайбу в КХЛ & Форвард магнитогорского «Металлурга» Евгений Малкин забросил первую шайбу после перехода в родной клуб. '
#  'Хоккеист сборной России отличился на 39-й минуте матча регулярного чемпионата КХЛ против «Льва» (в данный момент счет 6:1). За онлайн-трансляцией '
#  'матча «Магнитка» – «Лев» вы можете здесь . ВИДЕО')
# 0
#
#
# 17166
# ('67 минута. гол! РОССИ! Забивает под рукой угадавшего Буффона! 1:2!\n'
#  'Амброзини получил травму бедра & Полузащитник «Фиорентины» Массимо Амброзини досрочно покинул поле в матче с «Ювентусом» (4?2) из-за повреждения. '
#  'В середине первого тайма 36-летний хавбек получил травму бедра и был заменен на Матиаса Фернандеса. Степень серьезности повреждения будет выявлена '
#  'в ближайшие несколько дней. В этом сезоне Амброзини провел девять матчей за «Фиорентину» и отметился забитым голом.')
# 0
#
#
# 8705
# ('0 минута. Привет всем, кто не представляет своей жизни без хоккея!\n'
#  'Малкин забросил первую шайбу в КХЛ & Форвард магнитогорского «Металлурга» Евгений Малкин забросил первую шайбу после перехода в родной клуб. '
#  'Хоккеист сборной России отличился на 39-й минуте матча регулярного чемпионата КХЛ против «Льва» (в данный момент счет 6:1). За онлайн-трансляцией '
#  'матча «Магнитка» – «Лев» вы можете здесь . ВИДЕО')
# 0
#
#
# 10153
# ('57 минута. гол! 3:0! Криштиану Роналду! Забивает в сотом матче в ЛЧ! Растянули мадридцы оборону Дортмунда, и Модрич "тихим" пасом вывел Роналду на '
#  'свидание с вратарем.\n'
#  '«Реал» забил минимум 2 гола в десяти матчах подряд, повторив рекорд Лиги чемпионов & «Реал» забил два гола в первом тайме четвертьфинального матча '
#  'Лиги чемпионов с дортмундской «Боруссией» (2:0, перерыв). Таким образом, «Реал» забил минимум два гола в десяти матчах подряд, повторив рекорд '
#  'Лиги чемпионов, который в 2007-2009 годах установила «Севилья». Подробную статистику выступлений «Реала» в этом розыгрыше Лиги чемпионов смотрите '
#  'здесь . Sports.ru ведет онлайн-трансляцию матча «Реал» – «Боруссия» .')
# 0
#
#
# 25278
# ('61 минута. Портнягин пробил почти по центру - чуть правее центра. Заболотный ногами спасает! ВТОРОЙ отбитый пенальти за игру!\n'
#  '«Урал» – «Рубин». Заболотный отразил два пенальти & Голкипер «Урала» Николай Заболотный отбил два удара с пенальти в матче 14-го тура РФПЛ против '
#  '«Рубина» (0:3, второй тайм). На 13-й минуте 24-летний вратарь справился с попыткой Гекдениза Карадениза, который, тем не менее, отправил мяч в '
#  'сетку на добивании. На 60-й минуте Заболотный отразил удар с точки в исполнении Игоря Портнягина. Sports.ru ведет онлайн-трансляцию матча «Урал» – '
#  '«Рубин» .')
# 1
#
#
# 15479
# ('1 минута. ПОНЕСЛАСЬ!\n'
#  'ЦСКА – «Динамо». Никита Квартальнов подрался с Сопиным & Нападающий ЦСКА Никита Квартальнов подрался с форвардом «Динамо» Алексеем Сопиным. Эпизод '
# ...
#  'первом матче полуфинала Лиги чемпионов против «Атлетико». Сегодня ему исполнился 41 год и 198 дней Напомним, что Sports.ru ведет онлайн-трансляцию '
#  'матча «Атлетико» – «Челси» .')
# 0
#
#
# 24889
# ('61 минута. Внимание! Глушаков заходит на хет-трик! Пас под удар от Паршивлюка хорош. Защитники уже стерегут, не дают бить даже в касание.\n'
#  '«Спартак» – «Краснодар». Дикань отбил удар Комбарова с пенальти & Защитник «Спартака» Дмитрий Комбаров не реализовал пенальти в матче 16-го тура '
#  'РФПЛ с «Краснодаром» (2:1, первый тайм). На 34-й минуте главный судья встречи Игорь Низовцев назначил одиннадцатиметровый за фол Сергея Петрова на '
#  'Сергее Паршивлюке . Удар Комбарова с точки парировал голкипер «Краснодара» Андрей Дикань. Sports.ru ведет онлайн-трансляцию этого матча .')
# 0
#
#
# 8011
# ('0 минута. И с нова с вами! Бодро пожаловать на ответный матч за выход в групповой этап Лиги чемпионов между "Фенербахче" и "Спартаком".\n'
#  'Ари забил в матче с «Фенербахче» & Нападающий «Спартака» Ари открыл счет в матче с «Фенербахче». На 6-й минуте бразилец отличился после прострела '
#  'Макгиди с правого фланга. Напомним, что в первом матче плей-офф квалификации Лиги чемпионов красно-белые победили со счетом 2:1. Sports.ru ведет '
#  'текстовую трансляцию матча «Фенербахче» – «Спартак» .')
# 1
#
#
# 18619
# ('59 минута. гол!!! 4:0! Марио Фернандес простреливает во вратарскую, а там Дьяков в борьбе с Мусой отправляет мяч в свои  ворота!\n'
#  'ЦСКА – «Ростов». Еременко забил гол в дебютном матчей за армейцев & Полузащитник ЦСКА Роман Еременко довел до разгромного счет в матче 6-го тура '
#  'РФПЛ против «Ростова» (5:0, второй тайм). На 65-й минуте встречи 27-летний хавбек нанес удар в касание под перекладину ворот Стипе Плетикосы после '
#  'навеса Бибраса Натхо. Подробную статистику выступлений Еременко смотрите здесь . Sports.ru ведет онлайн-трансляцию матча ЦСКА – «Ростов» .')
# 0
#
#
# 15391
# ('46 минута. Траоре издали, мяч точно в руках у Гильерме.\n'
#  'Траоре не реализовал пенальти в матче с «Локомотивом» & Форвард «Кубани» Ласина Траоре не смог реализовать пенальти на 42-й минуте матче 33-го '
#  'тура чемпионата России против «Локомотива» (на данный момент счет 0:2). Нападающий ударил низом в угол ворот, но вратарь железнодорожников '
#  'Гильерме поймал мяч. Онлайн-трансляцию матча «Локомотив» – «Кубань» вы можете посмотреть здесь .')
# 0
#
#
# 13612
# ('4 минута. Безбородов шокирует "Анжи" и его болельщиков свистком в пользу ЦСКА, но у гостей мяч пока держится плохо.\n'
#  '«Анжи» – ЦСКА. Цауня получил красную карточку & Полузащитник ЦСКА Александр Цауня получил две желтые карточки на 19-й и 45-й минутах матча 18-го '
#  'тура чемпионата России против «Анжи». Главный арбитр встречи Владислав Безбородов удалил хавбека с поля. Подробную статистику выступлений Цауни вы '
#  'можете посмотреть здесь. Отметим, что Sports.ru ведет онлайн-трансляцию матча «Анжи» – ЦСКА .')
# 0
#
#
# 12316
# ('90 минута. Все, друзья. Спасибо, что были с нами в этот вечер до самого конца. Всем спокойного сна и побольше таких же взрывоопасных матчей, как '
#  'сегодняшний. Отбой.\n'
#  'Криштиану Роналду догнал Ди Стефано и стал вторым в списке лучших бомбардиров в истории «Реала» & Нападающий «Реала» Криштиану Роналду реализовал '
#  'пенальти в ответном полуфинале Лиги чемпионов с «Ювентусом» (1:0, первый тайм). Таким образом, капитан сборной Португалии забил 307-й гол за '
#  '«Реал» во всех турнирах, догнал Альфредо Ди Стефано и стал вторым в списке лучших бомбардиров в истории «Реала». Опережает Роналду только Рауль '
#  '(323). Отметим, что Криштиану Роналду забил 219 голов в примере, 21 – в Кубке Испании, 3 – в Суперкубке Испании, 62 – в Лиге чемпионов и 2 – в '
#  'Суперкубке Европы. Подробную статистику выступлений игрока смотрите здесь . Sports.ru ведет онлайн-трансляцию этой встречи.')
# 0
#
#
# 15219
# ('36 минута. Сычев выходит один на один с левого угла, прекрасно приняв мяч от Алиева. Форвард нанес удар с левой ноги из-под Федорива, но тот успел '
#  'подставить ногу. Угловой.\n'
#  'Федорив получил травму в игре с «Локомотивом» & Защитник «Амкара» Виталий Федорив получил травму в первом тайме матча 11-го тура премьер-лиги с '
#  '«Локомотивом». Футболист соревновался в скорости с Дмитрием Сычевым, дернул заднюю поверхность левого бедра и рухнул на газон. Поле он покинул на '
#  'медицинском автокаре. Вместо Федорива на поле на 38-й минуте вышел Вадим Гаглоев.')
# 0
#
#
# 11048
# ('56 минута. \n'
#  '«Зенит» – «Рубин». Кришито получил 2 желтые карточки в течение 3 минут & Защитник «Зенита» Доменико Кришито был удален в матче чемпионата России с '
#  '«Рубином» (1:1, второй тайм). Итальянец получил две желтые карточки в течение 3 минут. Первое предупреждение Кришито получил на 55-й минуте, '
#  'второе – на 58-й. Sports.ru ведет текстовую онлайн-трансляцию матча . Две грубые ошибки судьи Карасева в матче «Зенит» – «Рубин»')
# 0
#
#
# 23095
# ('88 минута. Суарес, такой Суарес! Толкнул и пробежался по спине Губочана, но арбитр молчит.\n'
#  '«Ливерпуль» – «Зенит». Суарес забил 600-й гол мерсисайдцев в еврокубках & Форвард «Ливерпуля» Луис Суарес забил второй гол в ответном матче 1/16 '
#  'финала Лиги Европы с «Зенитом» (3:1, второй тайм). Таким образом, Суарес забил 600-й гол мерсисайдцев в еврокубках, сообщает Infostrada. Sports.ru '
#  'ведет онлайн-трансляцию матча «Ливерпуль» – «Зенит» . ВИДЕО')
# 0
#
#
# 20922
# ('82 минута. Дармина навешивает за лицевую. Ван Галь так смотрит, будто запоминает, кто сделал эту пакость.\n'
#  '«Лестер» – «МЮ». Швайнштайгер забил первый гол за гостей & Полузащитник «Манчестер Юнайтед» Бастиан Швайнштайгер сравнял счет в матче 14-го тура '
#  'чемпионата Англии с «Лестером» (1:1, второй тайм). Таким образом, 31-летний экс-хавбек «Баварии» забил первый гол за клуб из Манчестера, сыграв 22 '
#  'матча во всех турнирах. Туром ранее, в матче с «Уотфордом» (2:1),  Швайнштайгер отдал первый голевой пас в составе «МЮ». Подробную статистику '
#  'выступлений игрока смотрите здесь . Sports.ru проводит текстовую онлайн-трансляцию матча .')
# 0
#
#
# 20843
# ('90 минута. Бендтнер бьет в обвод Акинфеева и попадает в ШТАНГУ!!\n'
#  'Акинфеев увеличил антирекорд Лиги чемпионов, пропустив в 32-м матче подряд & Нападающий «Вольфсбурга» Андре Шуррле забил гол в матче 5-го тура '
#  'группового этапа Лиги чемпионов с ЦСКА . Таким образом, вратарь армейцев Игорь Акинфеев увеличил антирекорд турнира, пропустив в 32-м матче '
#  'подряд. Напомним, что Акинфеев установил этот антирекорд, пропустив в 17-м подряд матче Лиги чемпионов в домашней игре с «Викторией» из Пльзени '
#  '(3:2) в позапрошлом сезоне. Бывший голкипер ПСВ Роналд Ватеррес пропускал в 16 матчах Лиги чемпионов подряд, экс-вратарь «Панатинаикоса» и '
#  '«Олимпиакоса» Антонис Никополидис – в 15. На счету Шэя Гивена, игравшего в Лиге чемпионов за «Ньюкасл», серия из 14 матчей. Антирекорд Акинфеева '
#  'учитывает только матчи в групповой стадии и плей-офф ЛЧ, пропущенные им мячи в играх квалификации турнира считаются отдельно и не идут в общий '
#  'зачет. Последний сухой матч Акинфеева в Лиге чемпионов состоялся 9 лет назад в матче с «Арсеналом» на «Эмирейтс» – 1 ноября 2006 года. Подробную '
#  'статистику Акинфеева смотрите здесь . Sports.ru ведет онлайн-трансляцию этого матча .')
# 0
#
#
# 22799
# ('45 минута. \n'
#  '«Ливерпуль» – «Арсенал». Жиру наступил на голову Шкртелу & Защитник «Ливерпуля» Мартин Шкртел получил травму головы в матче 17-го тура АПЛ с '
#  '«Арсеналом» (1:1, второй тайм). На 52-й минуте встречи 30-летний словак потерял равновесие и оказался на газоне после чего форвард гостей Оливье '
#  'Жиру наступил на голову Шкртелу. Врачи мерсисайдцев около четырех минут оказывали помощь футболисту, останавливая серьезное кровотечение. Затем '
#  'Шкртел смог продолжить встречу. Sports.ru проводит онлайн-трансляцию матча «Ливерпуль» – «Арсенал» .')
# 0
#
#
# 3639
# ('27 минута. гол! Кандрева забил. Сторари с углом не угадал. 1:0.\n'
#  '«Лацио» – «Ювентус». Буффон удален с поля и пропустит матч с «Интером» & Голкипер «Ювентуса» Джанлуиджи Буффон был удален с поля в матче 21-го '
#  'тура серии А против «Лацио» (0:1, первый тайм). Капитан туринцев заработал прямую красную карточку за фол на форварде «Лацио» Мирославе Клозе в '
#  'пределах своей штрафной площади. Хавбек римлян Антонио Кандрева сумел реализовать пенальти и вывел свою команду вперед. Отметим, что Буффон не '
#  'поможет «Ювентусу» в матче следующего тура серии А против «Интера». Sports.ru ведет онлайн-трансляцию матча «Лацио» – «Ювентус». ВИДЕО')
# 0
#
#
# 2794
# ('8 минута. Кержаков растяписто выходит из ворот и роняет мяч, оставшись лежать где-то поодаль! Василий Березуцкий успел пробить с разворота, но '
#  'махачкалинцы подстраховали своего кипера на ленточке!\n'
#  'ЦСКА – «Анжи». Разак дебютировал в составе махачкалинцев & Молодой полузащитник «Манчестер Сити», выступающий на правах аренды за «Анжи», '
#  'дебютировал в российской премьер-лиге. На 56-й минуте матча против ЦСКА 20-летний ивуариец вышел на поле, заменив Сердера Сердерова. К 68-й минуте '
#  'встречи счет команды пока не открыли. Sports.ru ведет онлайн-трансляцию матча ЦСКА – «Анжи».')
# 0
#
#
# 4914
# ('61 минута. гол! 3:0! Широков! Как же игра вместо интриги и намека на камбэк переросла в разгром за пару минут. А гол просто великолепен. Кришито '
#  'слева сильно прострелил, Широков подставил ногу в такт, организовав потрясающий "парашютик" за спину Диканю.\n'
#  'Файзулин забил гол в матче со «Спартаком» & Полузащитник «Зенита» Виктор Файзулин забил четвертый гол петербургского клуба в матче 4-го тура '
#  'чемпионата России против «Спартака». 26-летний хавбек отметился забитым мячом на 67-й минуте игры. Голевую передачу ему отдал Игорь Денисов. '
#  'Добавим, что матч между «Спартаком» и «Зенитом» проходит в эти минуты в Санкт-Петербурге. Sports.ru проводит текстовую трансляцию этой игры. ВИДЕО '
#  'Приложение Sports.ru для iPhone Приложение Sports.ru для Android')
# 0
#
#
# 17165
# ('64 минута. Тут же Думбия собирался совсем похоронитрь интригу, но рефери усмотрел нарушение в том, как ивуариец отвоевал себе мяч у Жоао Карлоса.\n'
#  'Думбия сделал первый хет-трик в чемпионате России & Форвард ЦСКА Сейду Думбия забил три мяча в матче 28-го тура чемпионата России с «Анжи» . Для '
#  '23-летнего игрока это первый хет-трик в чемпионате России. Ивуариец отличился на 24-й, 47-й и 80-й минутах встречи. Тем самым Думбия единолично '
#  'возглавил спор бомбардиров премьер-лиги с 19 голами. Более подробную статистику нападающего смотрите здесь . Видео голов и текстовую трансляцию '
#  'матча вы можете посмотреть здесь .')
# 0
#
#
# 20032
# ('87 минута. 87-я минута, но играть еще минут 15 с учетом оказания помощи Тиоте.\n'
#  'Тиоте получил травму в матче с «Челси» & Полузащитник «Ньюкасла» Шейк Тиоте получил повреждение в матче перенесенного 34-го тура чемпионата Англии '
#  'против «Челси» (в данный момент счет 1:0). Ивуариец неудачно приземлился на спину в одном из единоборств. На поле сразу же появились медики, '
#  'которые унесли игрока на специальных носилках. Отметим, что Тиоте был в сознании, когда его уносили с газона «Стэмфорд Бридж». Подробную '
#  'статистику выступлений Тиоте вы можете посмотреть здесь .')
# 1
#
#
# 14779
# ('33 минута. Первый гол 20-летнего нападающего в НХЛ! Такое запомнится, конечно.\n'
#  'НХЛ. Брэйден Шенн забил первый гол в лиге & Нападающий «Филадельфии» Брэйден Шенн в матче «Зимней классики» с «Рейнджерс» забил первый гол в НХЛ. '
#  'Он отличился на 33-й минуте после передачи защитника Мэтта Карла. В текущем сезоне 20-летний форвард провел 9 матчей. Подробную статистику его '
#  'выступлений смотрите здесь . Sports.ru ведет текстовую трансляцию матча «Филадельфия» – «Рейнджерс».')
# 1
#
#
# 12966
# ('23 минута. Дадонов и Антипин могли наносить броски из глубины чужой зоны, но в створ попасть не смогли. После броска Антипина шайба прошла в '
#  'миллиметрах от штанги!\n'
#  'Россия – Дания. Марченко забил первый гол на ЧМ & Защитник сборной России Алексей Марченко отметился заброшенной шайбой в игре против сборной '
#  'Дании на ЧМ-2016. В первом периоде Марченко удачно подключился к атаке и забросил гол после передач Евгения Дадонова и Никиты Зайцева. Таким '
#  'образом, 24-летний защитник забил свой первый гол на ЧМ. Sports.ru ведет текстовую онлайн-трансляцию матча .')
# 0
#
#
# 11513
# ('25 минута. Кришито очень жестко встретил Белозерова. Но чисто.\n'
#  '«Волга» – «Зенит». Кришито получил травму & Защитник «Зенита» Доменико Кришито получил травму в матче 15-го тура чемпионата России против «Волги» '
#  '(в данный момент счет 1:0). Футболист повредил колено в одном из стыков. На 63-й минуте матча вместо него на поле вышел защитник Ренат Янбаев. За '
#  'онлайн-трансляцией матча «Волга» – «Зенит» вы можете следить здесь .')
# 0
#
#
# 13527
# ('10 минута. Как и в эпизоде с первым голом, никто не мешал нападающему "Салавата" точно бросить с близкого расстояния. Замена вратаря у '
#  '"Авангарда". Алексей Кузнецов вместо Карри Ряме. Вот так.\n'
#  'Ряме уступил место в воротах Кузнецову на 10-й минуте матча с «Салаватом Юлаевым» & Голкипер «Авангарда» Карри Ряме на 10-й минуте матча с '
#  '«Салаватом Юлаевым» уступил место в воротах Алексею Кузнецову. К тому времени финн пропустил две шайбы. В нынешнем сезоне Кузнецов провел только 5 '
#  'матчей. Подробную статистику его выступлений смотрите здесь . Sports.ru ведет текстовую трансляцию матча «Салават Юлаев» – «Авангард».')
# 1
#
#
# 23047
# ('43 минута. гол! 2:1! Аллен. Правый фланг "Зенита" снова провалился, и Аллен со второй попытки пробил Малафеева.\n'
#  '«Ливерпуль» – «Зенит». Суарес забил 600-й гол мерсисайдцев в еврокубках & Форвард «Ливерпуля» Луис Суарес забил второй гол в ответном матче 1/16 '
#  'финала Лиги Европы с «Зенитом» (3:1, второй тайм). Таким образом, Суарес забил 600-й гол мерсисайдцев в еврокубках, сообщает Infostrada. Sports.ru '
#  'ведет онлайн-трансляцию матча «Ливерпуль» – «Зенит» . ВИДЕО')
# 0
#
#
# 16596
# ('34 минута. гол! ПЕДРО!!! Месси стоя увернулся от одного соперника, потом пробежался мимо еще парочки в штрафную и выкатил мяч направо - Педро '
#  'сходу уложил его под дальнюю штангу. 0:1!!\n'
#  '«Райо Вальекано» – «Барселона». Педро сделал первый хет-трик в чемпионате Испании & Полузащитник «Барселоны» Педро отметился голами на 33-й, 47-й '
#  'и 72-й минутах матча чемпионата Испании против «Райо Вальекано». Отметим, что это первый хет-трик игрока за все время выступления в Ла Лиге. '
#  'Подробную статистику выступлений Педро вы можете посмотреть здесь . Напомним, что Sports.ru ведет онлайн-трансляцию матча «Райо Вальекано» – '
#  '«Барселона» .')
# 1
#
#
# 13642
# ('39 минута. Тагирбеков получает устное предупреждение от Безбородова. Завелся человек не на шутку.\n'
#  '«Анжи» – ЦСКА. Цауня получил красную карточку & Полузащитник ЦСКА Александр Цауня получил две желтые карточки на 19-й и 45-й минутах матча 18-го '
#  'тура чемпионата России против «Анжи». Главный арбитр встречи Владислав Безбородов удалил хавбека с поля. Подробную статистику выступлений Цауни вы '
#  'можете посмотреть здесь. Отметим, что Sports.ru ведет онлайн-трансляцию матча «Анжи» – ЦСКА .')
# 0
#
#
# 21264
# ('26 минута. Коке в очередной раз ударил по ногам Месси и получил предупреждение.\n'
#  '«Барселона» – «Атлетико». Месси не реализовал пенальти & Лидер «Барселоны» Лионель Месси не смог реализовать пенальти на 89-й минуте ответного '
#  'матча за Суперкубок Испании против «Атлетико» (в данный момент счет 0:0). После удара капитана сборной Аргентины мяч угодил в перекладину. '
#  '«Барселона» – «Атлетико». Онлайн')
# 0
#  75%|███████▌  | 3/4 [3:32:58<1:11:00, 4260.94s/it]
#     <div>
#
#       <progress value='210' max='210' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [210/210 09:48, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.232900</td>
#       <td>0.097927</td>
#       <td>0.551451</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.133800</td>
#       <td>0.078687</td>
#       <td>0.611833</td>
#     </tr>
#   </tbody>
# </table><p>
# 100%|██████████| 4/4 [3:42:49<00:00, 3342.28s/it]

# %%
m = AutoModelForSequenceClassification.from_pretrained("/content/checkpoint-210")
trainer = BaalTransformersTrainer(
    model=m,
    args=training_args,
    train_dataset=active_set,
    eval_dataset=test_set,
    tokenizer=None,
    compute_metrics=compute_metrics
)
output = trainer.evaluate()
output
# Out:
#     <div>
#
#       <progress value='207' max='207' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [207/207 01:42]
#     </div>
# {'eval_loss': 0.08123039454221725,
#  'eval_f1': 0.6008344923504868,
#  'eval_runtime': 103.3494,
#  'eval_samples_per_second': 79.846,
#  'eval_steps_per_second': 2.003}

# %%
# !cp -r "/content/checkpoint-210" "/content/drive/MyDrive/RuSportSum/bald"
