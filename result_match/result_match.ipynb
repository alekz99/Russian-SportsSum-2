# %%
# !pip install --quiet transformers evaluate datasets baal
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 39.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 30.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 21.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 31.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 12.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 11.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.6/419.6 kB 21.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 18.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 11.0 MB/s eta 0:00:00

# %%
# !pip install --quiet --upgrade accelerate
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.1/219.1 kB 5.8 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp "/content/drive/MyDrive/RuSportSum/train.csv" /content/train.csv
# !cp "/content/drive/MyDrive/RuSportSum/eval.csv" /content/eval.csv

# %% [markdown]
# #### Разметка релевантных новостей с активным обучением

# %%
import os
import random
from copy import deepcopy

import numpy as np
import torch.backends
import transformers
import evaluate

from datasets import load_dataset
from tqdm import tqdm
from transformers import BertForSequenceClassification
from transformers import BertTokenizer, TrainingArguments
from transformers import set_seed

from transformers import (
    AutoConfig,
    AutoModelForSequenceClassification,
    AutoTokenizer,
    DataCollatorWithPadding,
    PretrainedConfig,
    set_seed,
    Trainer,
    TrainingArguments
)

transformers.utils.logging.set_verbosity_warning()

from baal.active import get_heuristic
from baal.active.dataset.nlp_datasets import (
    active_huggingface_dataset,
    HuggingFaceDatasets,
)
from baal.bayesian.dropout import patch_module
from baal.transformers_trainer_wrapper import BaalTransformersTrainer
from baal.active import get_heuristic, ActiveLearningDataset
from baal.active.dataset.base import Dataset

from typing import List
from pprint import pprint

SEED = 3

random.seed(SEED)
torch.manual_seed(SEED)

# Set tranformer seed to ensure that initial weights are identical
set_seed(SEED)

# %%
class CustomHuggingFaceDatasets(Dataset):
    """
    Support for `huggingface.datasets`: (https://github.com/huggingface/datasets).
    The purpose of this wrapper is to separate the labels from the rest of the sample information
    and make the dataset ready to be used by `baal.active.ActiveLearningDataset`.
    Args:
        dataset (Dataset): a dataset provided by huggingface.
        tokenizer (transformers.PreTrainedTokenizer): a tokenizer provided by huggingface.
        target_key (str): target key used in the dataset's dictionary.
        input_key (str): input key used in the dataset's dictionary.
        max_seq_len (int): max length of a sequence to be used for padding the shorter
            sequences.
    """

    def __init__(
        self,
        dataset,
        tokenizer=None,
        target_key: str = "label",
        input_key_1: str = "sentence1",
        input_key_2: str = "sentence1",
        max_seq_len: int = 400,
    ):
        self.dataset = dataset
        self.targets, self.text1, self.text2 = self.dataset[target_key], self.dataset[input_key_1], self.dataset[input_key_2]
        self.targets_list: List = np.unique(self.targets).tolist()
        self.input_ids, self.attention_masks = (
            self._tokenize(tokenizer, max_seq_len) if tokenizer else ([], [])
        )

    @property
    def num_classes(self):
        return len(self.targets_list)

    def _tokenize(self, tokenizer, max_seq_len):
        # For speed purposes, we should use fast tokenizers here, but that is up to the caller
        tokenized = tokenizer(
            self.text1,
            self.text2,
            add_special_tokens=True,
            max_length=max_seq_len,
            return_token_type_ids=False,
            padding="max_length",
            return_attention_mask=True,
            return_tensors="pt",
            truncation=True,
        )
        return tokenized["input_ids"], tokenized["attention_mask"]

    def label(self, idx: int, value: int):
        """Label the item.
        Args:
            idx: index to label
            value: Value to label the index.
        """
        self.targets[idx] = value

    def __len__(self):
        return len(self.text1)

    def __getitem__(self, idx):
        target = self.targets_list.index(self.targets[idx])

        return {
            "input_ids": self.input_ids[idx].flatten() if len(self.input_ids) > 0 else None,
            "inputs": self.text1[idx] + '\n' + self.text2[idx],
            "attention_mask": self.attention_masks[idx].flatten()
            if len(self.attention_masks) > 0
            else None,
            "label": torch.tensor(target, dtype=torch.long),
        }

def custom_active_huggingface_dataset(
    dataset,
    tokenizer=None,
    target_key: str = "label",
    input_key_1: str = "sentence1",
    input_key_2: str = "sentence2",
    max_seq_len: int = 400,
    **kwargs
):
    """
    Wrapping huggingface.datasets with baal.active.ActiveLearningDataset.
    Args:
        dataset (torch.utils.data.Dataset): a dataset provided by huggingface.
        tokenizer (transformers.PreTrainedTokenizer): a tokenizer provided by huggingface.
        target_key (str): target key used in the dataset's dictionary.
        input_key (str): input key used in the dataset's dictionary.
        max_seq_len (int): max length of a sequence to be used for padding the shorter sequences.
        kwargs (Dict): Parameters forwarded to 'ActiveLearningDataset'.
    Returns:
        an baal.active.ActiveLearningDataset object.
    """

    return ActiveLearningDataset(
        CustomHuggingFaceDatasets(dataset, tokenizer, target_key, input_key_1, input_key_2, max_seq_len), **kwargs
    )

# %% [markdown]
# Information on the hyperparms below
#
# * epoch: Number of times you want to run and AL loop
# * batch_size: The train and eval batch size for hf trainer arguments
# * model: Hugging Face Model
# * query_size: Number of samples you want to query at each AL iteration for labelling
# * heuristic: The acquisition function/heuristic based on which you want to query the important samples
# * iterations: The number of iterations you want to run for MCdropout to find the uncertanities
# * shuffle_prop: Additional Noise to counter selection bias
# * learning_epoch: Traing epochs for hugging face trainer

# %%
hyperparams = {
    "epoch": 4,
    "batch_size": 16,
    "model": "DeepPavlov/rubert-base-cased",
    "query_size": 50,
    "heuristic": "bald",
    "iterations": 10,
    "shuffle_prop": 0.05,
    "learning_epoch": 2,
}

# %%
# Check for CUDA
use_cuda = torch.cuda.is_available()
torch.backends.cudnn.benchmark = True

id2label = {0: "LABEL_0", 1: "LABEL_1"}
label2id = {"LABEL_0": 0, "LABEL_1": 1}

# Load Model
hf_model = AutoModelForSequenceClassification.from_pretrained(
    hyperparams["model"], num_labels=2, id2label=id2label, label2id=label2id
    )

# Setup tokenizer for model
tokenizer = AutoTokenizer.from_pretrained(hyperparams["model"])

# Enable dropouts for predictions
hf_model = patch_module(hf_model)

# Send model to device and setup cuda arguments
if use_cuda:
    hf_model.to("cuda:0")
    no_cuda = False
else:
    hf_model.to("cpu")
    no_cuda = True
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/642 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Some weights of the model checkpoint at DeepPavlov/rubert-base-cased were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at DeepPavlov/rubert-base-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading (…)okenizer_config.json:   0%|          | 0.00/24.0 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/1.65M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
# Define labels in your dataset
label_list = [0, 1]

# Load data from files
data = load_dataset("csv", data_files={'train': '/content/train.csv', 'eval': "/content/eval.csv"})
# Out:
# Downloading and preparing dataset csv/default to /root/.cache/huggingface/datasets/csv/default-5c97641fdcada1ed/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1...
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating eval split: 0 examples [00:00, ? examples/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-5c97641fdcada1ed/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
def get_label_from_data(active_dataset, data, target, input1, input2, indexes) -> List[int]:
    """
    Get labels from the active dataset, this assumes that you have
    already labelled some samples in your initial dataset

    Args:
    ----
    active_dataset : Active dataset which consists of train and pool

    indexes : Indexes of the points for which labels are to be fetched
    from the data

    Returns:
    ----
    labels: Returns the corresponding labels

    """

    labels = []

    # Now since you labelled points earlier now some part of pool has become train
    # so in order to get the pool indexes based on your 'original' data i.e
    # your raw_train_set. Make sure to user __pool_tp

    raw_data_idx = active_dataset._pool_to_oracle_index(indexes)

    for idx in raw_data_idx:
        #print(f"Adding labels for Raw data Index {idx} : {data[input1][idx]}")
        #print(f"Adding labels for Raw data Index {idx} : {data[input2][idx]}")

        label = data[target][idx]
        labels.append(label)
        #print(label)
        #print("\n")

    return labels

# %%
def get_label_human_oracle(active_dataset, indexes) -> List[int]:
    """
    Get labels from human oracle. During the AL loop some samples
    will go to the human labeller

    Args:
    ----
    active_dataset : Active dataset which consists of train and pool

    indexes : Indexes of the points for which labels are to be fetched
    from the data

    Returns:
    ----
    labels: Returns the corresponding labels

    """
    # List for corresponding labels
    labels = []

    skipped = []

    for sample_idx, idx in enumerate(indexes):

        while True:
            try:
                print(idx)
                pprint(active_dataset.pool.__getitem__(idx)['inputs'], width=150)
                label = int(input())
            except ValueError:
                print("Sorry, I didn't understand that.")
                continue
            if label != -1 and label not in label_list:
                print(f"Allowed labels are {label_list}")
                continue
            if label == -1:
                print("Skipping this sample")
                skipped.append(sample_idx)
                break
            else:
                labels.append(label)
                break
        print("\n")

    indexes_upd = np.delete(indexes, skipped)

    return labels, indexes_upd

# %%
#small_data = data['train'].select(range(10_000))
small_data = data['train']

active_set = custom_active_huggingface_dataset(
    small_data,
    tokenizer=tokenizer,
    target_key='result_match',
    input_key_1='name_body',
    input_key_2='last_part_content'
)

active_set.can_label = True

# 700 первых объектов набора данных
label_from_data = get_label_from_data(active_set, small_data, 'result_match', 'name_body', 'last_part_content', range(700))

active_set.label(
    range(700),
    label_from_data,
)

valid_set = CustomHuggingFaceDatasets(data['eval'], tokenizer=tokenizer, target_key='result_match', input_key_1='name_body', input_key_2='last_part_content')

active_set, test_set = active_set, valid_set

# %%
# Setup Heuristics
heuristic = get_heuristic(
    hyperparams["heuristic"], hyperparams["shuffle_prop"]
)

# Model save checkpoint
save_checkpoint = 2

metric = evaluate.load("f1")

def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    predictions = np.argmax(predictions, axis=1)
    return metric.compute(predictions=predictions, references=labels)

# Keep track of initial model weights
init_weights = deepcopy(hf_model.state_dict())

training_args = TrainingArguments(
    output_dir=".",
    num_train_epochs=hyperparams["learning_epoch"],
    per_device_train_batch_size=hyperparams["batch_size"],
    per_device_eval_batch_size=hyperparams["batch_size"],
    weight_decay=0.01,
    logging_steps=10,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True
)

# Active Learning Trainer Wrapper
baal_trainer = BaalTransformersTrainer(
    model=hf_model,
    args=training_args,
    train_dataset=active_set,
    eval_dataset=test_set,
    tokenizer=None,
    compute_metrics=compute_metrics
)
# Out:
# Downloading builder script:   0%|          | 0.00/6.77k [00:00<?, ?B/s]

# %%
logs = []
last_epoch = hyperparams["epoch"] - 1

for epoch in tqdm(range(hyperparams["epoch"])):
    # we use the default setup of HuggingFace for training (ex: epoch=1).
    # The setup is adjustable when BaalHuggingFaceTrainer is defined.
    baal_trainer.train()
    print("\n")

    # Validation!
    #eval_metrics = baal_trainer.evaluate()
    #print("\n")

    if (epoch != last_epoch):
      # MCdropout to gather uncertanities
      predictions = baal_trainer.predict_on_dataset(
          active_set.pool, iterations=hyperparams["iterations"]
      )
      print("\n")

      # Acquistion of the most informative and diverse samples based on BatchBALD
      top_uncertainty = heuristic(predictions)[: hyperparams.get("query_size", 1)]

      # Send the samples for labelling from human oracle
      label_from_oracle, points_to_label_oracle = get_label_human_oracle(
          active_set, top_uncertainty
      )

      # Label active dataset
      active_set.label(points_to_label_oracle, label_from_oracle)

      # We reset the model weights to relearn from the new trainset.
      baal_trainer.load_state_dict(init_weights)
      baal_trainer.lr_scheduler = None

      active_logs = {
          "epoch": epoch,
          "labeled_data": active_set.labelled_map,
          "Next Training set size": len(active_set),
      }
      logs.append({**active_logs})
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/optimization.py:407: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#     <div>
#
#       <progress value='88' max='88' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [88/88 02:48, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.449400</td>
#       <td>0.531894</td>
#       <td>0.796209</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.209000</td>
#       <td>0.241835</td>
#       <td>0.936759</td>
#     </tr>
#   </tbody>
# </table><p>
# [275-MainThread  ] [baal.transformers_trainer_wrapper:predict_on_dataset_generator:67] 2023-05-28T10:48:54.829879Z [info     ] Start Predict                  dataset=11764
#   0%|          | 0/736 [00:00<?, ?it/s]
#   0%|          | 1/736 [00:04<53:09,  4.34s/it]
#   0%|          | 2/736 [00:08<51:54,  4.24s/it]
#   0%|          | 3/736 [00:12<51:49,  4.24s/it]
#   1%|          | 4/736 [00:17<52:07,  4.27s/it]
#   1%|          | 5/736 [00:21<52:35,  4.32s/it]
#   1%|          | 6/736 [00:25<53:07,  4.37s/it]
#   1%|          | 7/736 [00:30<53:42,  4.42s/it]
#   1%|          | 8/736 [00:35<54:13,  4.47s/it]
#   1%|          | 9/736 [00:39<54:27,  4.49s/it]
#   1%|▏         | 10/736 [00:44<54:20,  4.49s/it]
#   1%|▏         | 11/736 [00:48<53:59,  4.47s/it]
#   2%|▏         | 12/736 [00:52<53:39,  4.45s/it]
#   2%|▏         | 13/736 [00:57<53:10,  4.41s/it]
#   2%|▏         | 14/736 [01:01<52:45,  4.38s/it]
#   2%|▏         | 15/736 [01:05<52:17,  4.35s/it]
#   2%|▏         | 16/736 [01:10<51:50,  4.32s/it]
#   2%|▏         | 17/736 [01:14<51:26,  4.29s/it]
#   2%|▏         | 18/736 [01:18<51:07,  4.27s/it]
#   3%|▎         | 19/736 [01:22<50:51,  4.26s/it]
#   3%|▎         | 20/736 [01:26<50:40,  4.25s/it]
#   3%|▎         | 21/736 [01:31<50:32,  4.24s/it]
#   3%|▎         | 22/736 [01:35<50:29,  4.24s/it]
#   3%|▎         | 23/736 [01:39<50:28,  4.25s/it]
#   3%|▎         | 24/736 [01:43<50:32,  4.26s/it]
#   3%|▎         | 25/736 [01:48<50:38,  4.27s/it]
#   4%|▎         | 26/736 [01:52<50:47,  4.29s/it]
#   4%|▎         | 27/736 [01:56<50:51,  4.30s/it]
#   4%|▍         | 28/736 [02:01<50:58,  4.32s/it]
#   4%|▍         | 29/736 [02:05<50:59,  4.33s/it]
#   4%|▍         | 30/736 [02:10<51:03,  4.34s/it]
#   4%|▍         | 31/736 [02:14<51:00,  4.34s/it]
#   4%|▍         | 32/736 [02:18<50:54,  4.34s/it]
#   4%|▍         | 33/736 [02:23<50:51,  4.34s/it]
#   5%|▍         | 34/736 [02:27<50:42,  4.33s/it]
#   5%|▍         | 35/736 [02:31<50:35,  4.33s/it]
#   5%|▍         | 36/736 [02:35<50:26,  4.32s/it]
#   5%|▌         | 37/736 [02:40<50:15,  4.31s/it]
#   5%|▌         | 38/736 [02:44<50:08,  4.31s/it]
#   5%|▌         | 39/736 [02:48<49:59,  4.30s/it]
#   5%|▌         | 40/736 [02:53<49:50,  4.30s/it]
#   6%|▌         | 41/736 [02:57<49:44,  4.29s/it]
#   6%|▌         | 42/736 [03:01<49:37,  4.29s/it]
#   6%|▌         | 43/736 [03:06<49:32,  4.29s/it]
#   6%|▌         | 44/736 [03:10<49:27,  4.29s/it]
#   6%|▌         | 45/736 [03:14<49:23,  4.29s/it]
#   6%|▋         | 46/736 [03:18<49:20,  4.29s/it]
#   6%|▋         | 47/736 [03:23<49:17,  4.29s/it]
#   7%|▋         | 48/736 [03:27<49:14,  4.29s/it]
#   7%|▋         | 49/736 [03:31<49:11,  4.30s/it]
#   7%|▋         | 50/736 [03:36<49:09,  4.30s/it]
#   7%|▋         | 51/736 [03:40<49:06,  4.30s/it]
#   7%|▋         | 52/736 [03:44<49:02,  4.30s/it]
#   7%|▋         | 53/736 [03:49<49:00,  4.31s/it]
#   7%|▋         | 54/736 [03:53<48:56,  4.31s/it]
#   7%|▋         | 55/736 [03:57<48:53,  4.31s/it]
#   8%|▊         | 56/736 [04:01<48:51,  4.31s/it]
#   8%|▊         | 57/736 [04:06<48:48,  4.31s/it]
#   8%|▊         | 58/736 [04:10<48:46,  4.32s/it]
#   8%|▊         | 59/736 [04:14<48:42,  4.32s/it]
#   8%|▊         | 60/736 [04:19<48:35,  4.31s/it]
#   8%|▊         | 61/736 [04:23<48:33,  4.32s/it]
#   8%|▊         | 62/736 [04:27<48:31,  4.32s/it]
#   9%|▊         | 63/736 [04:32<48:27,  4.32s/it]
#   9%|▊         | 64/736 [04:36<48:20,  4.32s/it]
#   9%|▉         | 65/736 [04:40<48:14,  4.31s/it]
#   9%|▉         | 66/736 [04:45<48:12,  4.32s/it]
#   9%|▉         | 67/736 [04:49<48:10,  4.32s/it]
#   9%|▉         | 68/736 [04:53<48:06,  4.32s/it]
#   9%|▉         | 69/736 [04:58<48:02,  4.32s/it]
#  10%|▉         | 70/736 [05:02<47:58,  4.32s/it]
#  10%|▉         | 71/736 [05:06<47:53,  4.32s/it]
#  10%|▉         | 72/736 [05:11<47:50,  4.32s/it]
#  10%|▉         | 73/736 [05:15<47:46,  4.32s/it]
#  10%|█         | 74/736 [05:19<47:41,  4.32s/it]
#  10%|█         | 75/736 [05:24<47:38,  4.32s/it]
#  10%|█         | 76/736 [05:28<47:34,  4.32s/it]
#  10%|█         | 77/736 [05:32<47:29,  4.32s/it]
#  11%|█         | 78/736 [05:37<47:25,  4.32s/it]
#  11%|█         | 79/736 [05:41<47:21,  4.32s/it]
#  11%|█         | 80/736 [05:45<47:18,  4.33s/it]
#  11%|█         | 81/736 [05:49<47:13,  4.33s/it]
#  11%|█         | 82/736 [05:54<47:08,  4.32s/it]
#  11%|█▏        | 83/736 [05:58<47:03,  4.32s/it]
#  11%|█▏        | 84/736 [06:02<46:59,  4.32s/it]
#  12%|█▏        | 85/736 [06:07<46:55,  4.32s/it]
#  12%|█▏        | 86/736 [06:11<46:51,  4.32s/it]
#  12%|█▏        | 87/736 [06:15<46:46,  4.32s/it]
#  12%|█▏        | 88/736 [06:20<46:42,  4.32s/it]
#  12%|█▏        | 89/736 [06:24<46:37,  4.32s/it]
#  12%|█▏        | 90/736 [06:28<46:32,  4.32s/it]
#  12%|█▏        | 91/736 [06:33<46:28,  4.32s/it]
#  12%|█▎        | 92/736 [06:37<46:24,  4.32s/it]
#  13%|█▎        | 93/736 [06:41<46:20,  4.32s/it]
#  13%|█▎        | 94/736 [06:46<46:17,  4.33s/it]
#  13%|█▎        | 95/736 [06:50<46:13,  4.33s/it]
#  13%|█▎        | 96/736 [06:54<46:08,  4.33s/it]
#  13%|█▎        | 97/736 [06:59<46:03,  4.33s/it]
#  13%|█▎        | 98/736 [07:03<45:59,  4.32s/it]
#  13%|█▎        | 99/736 [07:07<45:54,  4.32s/it]
#  14%|█▎        | 100/736 [07:12<45:49,  4.32s/it]
#  14%|█▎        | 101/736 [07:16<45:46,  4.33s/it]
#  14%|█▍        | 102/736 [07:20<45:44,  4.33s/it]
#  14%|█▍        | 103/736 [07:25<45:39,  4.33s/it]
#  14%|█▍        | 104/736 [07:29<45:34,  4.33s/it]
#  14%|█▍        | 105/736 [07:33<45:30,  4.33s/it]
#  14%|█▍        | 106/736 [07:38<45:25,  4.33s/it]
#  15%|█▍        | 107/736 [07:42<45:21,  4.33s/it]
#  15%|█▍        | 108/736 [07:46<45:16,  4.33s/it]
#  15%|█▍        | 109/736 [07:51<45:12,  4.33s/it]
#  15%|█▍        | 110/736 [07:55<45:08,  4.33s/it]
#  15%|█▌        | 111/736 [07:59<45:03,  4.33s/it]
#  15%|█▌        | 112/736 [08:04<44:58,  4.32s/it]
#  15%|█▌        | 113/736 [08:08<44:54,  4.33s/it]
#  15%|█▌        | 114/736 [08:12<44:50,  4.32s/it]
#  16%|█▌        | 115/736 [08:17<44:45,  4.32s/it]
#  16%|█▌        | 116/736 [08:21<44:41,  4.33s/it]
#  16%|█▌        | 117/736 [08:25<44:37,  4.33s/it]
#  16%|█▌        | 118/736 [08:30<44:32,  4.32s/it]
#  16%|█▌        | 119/736 [08:34<44:28,  4.32s/it]
#  16%|█▋        | 120/736 [08:38<44:23,  4.32s/it]
#  16%|█▋        | 121/736 [08:42<44:19,  4.32s/it]
#  17%|█▋        | 122/736 [08:47<44:17,  4.33s/it]
#  17%|█▋        | 123/736 [08:51<44:13,  4.33s/it]
#  17%|█▋        | 124/736 [08:55<44:08,  4.33s/it]
#  17%|█▋        | 125/736 [09:00<44:03,  4.33s/it]
#  17%|█▋        | 126/736 [09:04<44:00,  4.33s/it]
#  17%|█▋        | 127/736 [09:08<43:55,  4.33s/it]
#  17%|█▋        | 128/736 [09:13<43:50,  4.33s/it]
#  18%|█▊        | 129/736 [09:17<43:46,  4.33s/it]
#  18%|█▊        | 130/736 [09:21<43:41,  4.33s/it]
#  18%|█▊        | 131/736 [09:26<43:35,  4.32s/it]
#  18%|█▊        | 132/736 [09:30<43:31,  4.32s/it]
#  18%|█▊        | 133/736 [09:34<43:26,  4.32s/it]
#  18%|█▊        | 134/736 [09:39<43:22,  4.32s/it]
#  18%|█▊        | 135/736 [09:43<43:18,  4.32s/it]
#  18%|█▊        | 136/736 [09:47<43:14,  4.32s/it]
#  19%|█▊        | 137/736 [09:52<43:09,  4.32s/it]
#  19%|█▉        | 138/736 [09:56<43:05,  4.32s/it]
#  19%|█▉        | 139/736 [10:00<43:01,  4.32s/it]
#  19%|█▉        | 140/736 [10:05<42:57,  4.32s/it]
#  19%|█▉        | 141/736 [10:09<42:53,  4.33s/it]
#  19%|█▉        | 142/736 [10:13<42:49,  4.33s/it]
#  19%|█▉        | 143/736 [10:18<42:44,  4.33s/it]
#  20%|█▉        | 144/736 [10:22<42:40,  4.33s/it]
#  20%|█▉        | 145/736 [10:26<42:36,  4.33s/it]
#  20%|█▉        | 146/736 [10:31<42:31,  4.32s/it]
#  20%|█▉        | 147/736 [10:35<42:27,  4.32s/it]
#  20%|██        | 148/736 [10:39<42:23,  4.33s/it]
#  20%|██        | 149/736 [10:44<42:19,  4.33s/it]
#  20%|██        | 150/736 [10:48<42:14,  4.33s/it]
#  21%|██        | 151/736 [10:52<42:12,  4.33s/it]
#  21%|██        | 152/736 [10:57<42:07,  4.33s/it]
#  21%|██        | 153/736 [11:01<42:01,  4.33s/it]
#  21%|██        | 154/736 [11:05<41:56,  4.32s/it]
#  21%|██        | 155/736 [11:10<41:52,  4.32s/it]
#  21%|██        | 156/736 [11:14<41:49,  4.33s/it]
#  21%|██▏       | 157/736 [11:18<41:45,  4.33s/it]
#  21%|██▏       | 158/736 [11:23<41:41,  4.33s/it]
#  22%|██▏       | 159/736 [11:27<41:36,  4.33s/it]
#  22%|██▏       | 160/736 [11:31<41:31,  4.33s/it]
#  22%|██▏       | 161/736 [11:36<41:27,  4.33s/it]
#  22%|██▏       | 162/736 [11:40<41:22,  4.33s/it]
#  22%|██▏       | 163/736 [11:44<41:18,  4.33s/it]
#  22%|██▏       | 164/736 [11:48<41:13,  4.32s/it]
#  22%|██▏       | 165/736 [11:53<41:09,  4.32s/it]
#  23%|██▎       | 166/736 [11:57<41:07,  4.33s/it]
#  23%|██▎       | 167/736 [12:01<41:03,  4.33s/it]
#  23%|██▎       | 168/736 [12:06<40:57,  4.33s/it]
#  23%|██▎       | 169/736 [12:10<40:51,  4.32s/it]
#  23%|██▎       | 170/736 [12:14<40:47,  4.32s/it]
#  23%|██▎       | 171/736 [12:19<40:44,  4.33s/it]
#  23%|██▎       | 172/736 [12:23<40:39,  4.33s/it]
#  24%|██▎       | 173/736 [12:27<40:36,  4.33s/it]
#  24%|██▎       | 174/736 [12:32<40:30,  4.33s/it]
#  24%|██▍       | 175/736 [12:36<40:26,  4.32s/it]
#  24%|██▍       | 176/736 [12:40<40:20,  4.32s/it]
#  24%|██▍       | 177/736 [12:45<40:13,  4.32s/it]
#  24%|██▍       | 178/736 [12:49<40:06,  4.31s/it]
#  24%|██▍       | 179/736 [12:53<39:56,  4.30s/it]
#  24%|██▍       | 180/736 [12:58<39:50,  4.30s/it]
#  25%|██▍       | 181/736 [13:02<39:44,  4.30s/it]
#  25%|██▍       | 182/736 [13:06<39:41,  4.30s/it]
#  25%|██▍       | 183/736 [13:10<39:38,  4.30s/it]
#  25%|██▌       | 184/736 [13:15<39:35,  4.30s/it]
#  25%|██▌       | 185/736 [13:19<39:33,  4.31s/it]
#  25%|██▌       | 186/736 [13:23<39:32,  4.31s/it]
#  25%|██▌       | 187/736 [13:28<39:31,  4.32s/it]
#  26%|██▌       | 188/736 [13:32<39:29,  4.32s/it]
#  26%|██▌       | 189/736 [13:36<39:26,  4.33s/it]
#  26%|██▌       | 190/736 [13:41<39:23,  4.33s/it]
#  26%|██▌       | 191/736 [13:45<39:21,  4.33s/it]
#  26%|██▌       | 192/736 [13:49<39:19,  4.34s/it]
#  26%|██▌       | 193/736 [13:54<39:15,  4.34s/it]
#  26%|██▋       | 194/736 [13:58<39:11,  4.34s/it]
#  26%|██▋       | 195/736 [14:02<39:08,  4.34s/it]
#  27%|██▋       | 196/736 [14:07<39:03,  4.34s/it]
#  27%|██▋       | 197/736 [14:11<38:59,  4.34s/it]
#  27%|██▋       | 198/736 [14:15<38:52,  4.34s/it]
#  27%|██▋       | 199/736 [14:20<38:47,  4.33s/it]
#  27%|██▋       | 200/736 [14:24<38:42,  4.33s/it]
#  27%|██▋       | 201/736 [14:28<38:36,  4.33s/it]
#  27%|██▋       | 202/736 [14:33<38:32,  4.33s/it]
#  28%|██▊       | 203/736 [14:37<38:26,  4.33s/it]
#  28%|██▊       | 204/736 [14:41<38:21,  4.33s/it]
#  28%|██▊       | 205/736 [14:46<38:16,  4.33s/it]
#  28%|██▊       | 206/736 [14:50<38:09,  4.32s/it]
#  28%|██▊       | 207/736 [14:54<38:02,  4.31s/it]
#  28%|██▊       | 208/736 [14:59<37:56,  4.31s/it]
#  28%|██▊       | 209/736 [15:03<37:50,  4.31s/it]
#  29%|██▊       | 210/736 [15:07<37:43,  4.30s/it]
#  29%|██▊       | 211/736 [15:12<37:38,  4.30s/it]
#  29%|██▉       | 212/736 [15:16<37:33,  4.30s/it]
#  29%|██▉       | 213/736 [15:20<37:29,  4.30s/it]
#  29%|██▉       | 214/736 [15:24<37:24,  4.30s/it]
#  29%|██▉       | 215/736 [15:29<37:20,  4.30s/it]
#  29%|██▉       | 216/736 [15:33<37:15,  4.30s/it]
#  29%|██▉       | 217/736 [15:37<37:10,  4.30s/it]
#  30%|██▉       | 218/736 [15:42<37:06,  4.30s/it]
#  30%|██▉       | 219/736 [15:46<37:00,  4.30s/it]
#  30%|██▉       | 220/736 [15:50<36:58,  4.30s/it]
#  30%|███       | 221/736 [15:55<36:54,  4.30s/it]
#  30%|███       | 222/736 [15:59<36:48,  4.30s/it]
#  30%|███       | 223/736 [16:03<36:44,  4.30s/it]
#  30%|███       | 224/736 [16:07<36:41,  4.30s/it]
#  31%|███       | 225/736 [16:12<36:37,  4.30s/it]
#  31%|███       | 226/736 [16:16<36:33,  4.30s/it]
#  31%|███       | 227/736 [16:20<36:28,  4.30s/it]
#  31%|███       | 228/736 [16:25<36:25,  4.30s/it]
#  31%|███       | 229/736 [16:29<36:20,  4.30s/it]
#  31%|███▏      | 230/736 [16:33<36:16,  4.30s/it]
#  31%|███▏      | 231/736 [16:38<36:11,  4.30s/it]
#  32%|███▏      | 232/736 [16:42<36:06,  4.30s/it]
#  32%|███▏      | 233/736 [16:46<36:01,  4.30s/it]
#  32%|███▏      | 234/736 [16:50<35:58,  4.30s/it]
#  32%|███▏      | 235/736 [16:55<35:54,  4.30s/it]
#  32%|███▏      | 236/736 [16:59<35:50,  4.30s/it]
#  32%|███▏      | 237/736 [17:03<35:45,  4.30s/it]
#  32%|███▏      | 238/736 [17:08<35:41,  4.30s/it]
#  32%|███▏      | 239/736 [17:12<35:36,  4.30s/it]
#  33%|███▎      | 240/736 [17:16<35:32,  4.30s/it]
#  33%|███▎      | 241/736 [17:21<35:28,  4.30s/it]
#  33%|███▎      | 242/736 [17:25<35:24,  4.30s/it]
#  33%|███▎      | 243/736 [17:29<35:20,  4.30s/it]
#  33%|███▎      | 244/736 [17:33<35:15,  4.30s/it]
#  33%|███▎      | 245/736 [17:38<35:12,  4.30s/it]
#  33%|███▎      | 246/736 [17:42<35:09,  4.30s/it]
#  34%|███▎      | 247/736 [17:46<35:04,  4.30s/it]
#  34%|███▎      | 248/736 [17:51<35:01,  4.31s/it]
#  34%|███▍      | 249/736 [17:55<34:59,  4.31s/it]
#  34%|███▍      | 250/736 [17:59<34:55,  4.31s/it]
#  34%|███▍      | 251/736 [18:04<34:51,  4.31s/it]
#  34%|███▍      | 252/736 [18:08<34:48,  4.31s/it]
#  34%|███▍      | 253/736 [18:12<34:44,  4.32s/it]
#  35%|███▍      | 254/736 [18:17<34:41,  4.32s/it]
#  35%|███▍      | 255/736 [18:21<34:37,  4.32s/it]
#  35%|███▍      | 256/736 [18:25<34:33,  4.32s/it]
#  35%|███▍      | 257/736 [18:30<34:29,  4.32s/it]
#  35%|███▌      | 258/736 [18:34<34:25,  4.32s/it]
#  35%|███▌      | 259/736 [18:38<34:21,  4.32s/it]
#  35%|███▌      | 260/736 [18:43<34:16,  4.32s/it]
#  35%|███▌      | 261/736 [18:47<34:13,  4.32s/it]
#  36%|███▌      | 262/736 [18:51<34:10,  4.33s/it]
#  36%|███▌      | 263/736 [18:56<34:05,  4.33s/it]
#  36%|███▌      | 264/736 [19:00<34:02,  4.33s/it]
#  36%|███▌      | 265/736 [19:04<33:57,  4.33s/it]
#  36%|███▌      | 266/736 [19:08<33:53,  4.33s/it]
#  36%|███▋      | 267/736 [19:13<33:49,  4.33s/it]
#  36%|███▋      | 268/736 [19:17<33:44,  4.33s/it]
#  37%|███▋      | 269/736 [19:21<33:40,  4.33s/it]
#  37%|███▋      | 270/736 [19:26<33:35,  4.33s/it]
#  37%|███▋      | 271/736 [19:30<33:33,  4.33s/it]
#  37%|███▋      | 272/736 [19:34<33:28,  4.33s/it]
#  37%|███▋      | 273/736 [19:39<33:24,  4.33s/it]
#  37%|███▋      | 274/736 [19:43<33:20,  4.33s/it]
#  37%|███▋      | 275/736 [19:47<33:16,  4.33s/it]
#  38%|███▊      | 276/736 [19:52<33:13,  4.33s/it]
#  38%|███▊      | 277/736 [19:56<33:08,  4.33s/it]
#  38%|███▊      | 278/736 [20:00<33:05,  4.33s/it]
#  38%|███▊      | 279/736 [20:05<33:01,  4.34s/it]
#  38%|███▊      | 280/736 [20:09<32:56,  4.33s/it]
#  38%|███▊      | 281/736 [20:13<32:51,  4.33s/it]
#  38%|███▊      | 282/736 [20:18<32:46,  4.33s/it]
#  38%|███▊      | 283/736 [20:22<32:42,  4.33s/it]
#  39%|███▊      | 284/736 [20:26<32:38,  4.33s/it]
#  39%|███▊      | 285/736 [20:31<32:36,  4.34s/it]
#  39%|███▉      | 286/736 [20:35<32:31,  4.34s/it]
#  39%|███▉      | 287/736 [20:39<32:27,  4.34s/it]
#  39%|███▉      | 288/736 [20:44<32:23,  4.34s/it]
#  39%|███▉      | 289/736 [20:48<32:19,  4.34s/it]
#  39%|███▉      | 290/736 [20:53<32:15,  4.34s/it]
#  40%|███▉      | 291/736 [20:57<32:11,  4.34s/it]
#  40%|███▉      | 292/736 [21:01<32:07,  4.34s/it]
#  40%|███▉      | 293/736 [21:06<32:04,  4.34s/it]
#  40%|███▉      | 294/736 [21:10<31:59,  4.34s/it]
#  40%|████      | 295/736 [21:14<31:55,  4.34s/it]
#  40%|████      | 296/736 [21:19<31:50,  4.34s/it]
#  40%|████      | 297/736 [21:23<31:45,  4.34s/it]
#  40%|████      | 298/736 [21:27<31:42,  4.34s/it]
#  41%|████      | 299/736 [21:32<31:38,  4.34s/it]
#  41%|████      | 300/736 [21:36<31:33,  4.34s/it]
#  41%|████      | 301/736 [21:40<31:29,  4.34s/it]
#  41%|████      | 302/736 [21:45<31:25,  4.35s/it]
#  41%|████      | 303/736 [21:49<31:21,  4.35s/it]
#  41%|████▏     | 304/736 [21:53<31:16,  4.34s/it]
#  41%|████▏     | 305/736 [21:58<31:12,  4.34s/it]
#  42%|████▏     | 306/736 [22:02<31:07,  4.34s/it]
#  42%|████▏     | 307/736 [22:06<31:02,  4.34s/it]
#  42%|████▏     | 308/736 [22:11<30:57,  4.34s/it]
#  42%|████▏     | 309/736 [22:15<30:53,  4.34s/it]
#  42%|████▏     | 310/736 [22:19<30:47,  4.34s/it]
#  42%|████▏     | 311/736 [22:24<30:43,  4.34s/it]
#  42%|████▏     | 312/736 [22:28<30:38,  4.34s/it]
#  43%|████▎     | 313/736 [22:32<30:32,  4.33s/it]
#  43%|████▎     | 314/736 [22:37<30:27,  4.33s/it]
#  43%|████▎     | 315/736 [22:41<30:22,  4.33s/it]
#  43%|████▎     | 316/736 [22:45<30:17,  4.33s/it]
#  43%|████▎     | 317/736 [22:50<30:12,  4.33s/it]
#  43%|████▎     | 318/736 [22:54<30:07,  4.32s/it]
#  43%|████▎     | 319/736 [22:58<30:03,  4.32s/it]
#  43%|████▎     | 320/736 [23:03<29:58,  4.32s/it]
#  44%|████▎     | 321/736 [23:07<29:54,  4.32s/it]
#  44%|████▍     | 322/736 [23:11<29:50,  4.32s/it]
#  44%|████▍     | 323/736 [23:16<29:46,  4.32s/it]
#  44%|████▍     | 324/736 [23:20<29:41,  4.32s/it]
#  44%|████▍     | 325/736 [23:24<29:36,  4.32s/it]
#  44%|████▍     | 326/736 [23:29<29:32,  4.32s/it]
#  44%|████▍     | 327/736 [23:33<29:27,  4.32s/it]
#  45%|████▍     | 328/736 [23:37<29:22,  4.32s/it]
#  45%|████▍     | 329/736 [23:42<29:18,  4.32s/it]
#  45%|████▍     | 330/736 [23:46<29:14,  4.32s/it]
#  45%|████▍     | 331/736 [23:50<29:09,  4.32s/it]
#  45%|████▌     | 332/736 [23:54<29:03,  4.31s/it]
#  45%|████▌     | 333/736 [23:59<28:58,  4.31s/it]
#  45%|████▌     | 334/736 [24:03<28:54,  4.31s/it]
#  46%|████▌     | 335/736 [24:07<28:49,  4.31s/it]
#  46%|████▌     | 336/736 [24:12<28:45,  4.31s/it]
#  46%|████▌     | 337/736 [24:16<28:40,  4.31s/it]
#  46%|████▌     | 338/736 [24:20<28:36,  4.31s/it]
#  46%|████▌     | 339/736 [24:25<28:31,  4.31s/it]
#  46%|████▌     | 340/736 [24:29<28:26,  4.31s/it]
#  46%|████▋     | 341/736 [24:33<28:21,  4.31s/it]
#  46%|████▋     | 342/736 [24:38<28:17,  4.31s/it]
#  47%|████▋     | 343/736 [24:42<28:13,  4.31s/it]
#  47%|████▋     | 344/736 [24:46<28:08,  4.31s/it]
#  47%|████▋     | 345/736 [24:50<28:04,  4.31s/it]
#  47%|████▋     | 346/736 [24:55<28:00,  4.31s/it]
#  47%|████▋     | 347/736 [24:59<27:55,  4.31s/it]
#  47%|████▋     | 348/736 [25:03<27:51,  4.31s/it]
#  47%|████▋     | 349/736 [25:08<27:47,  4.31s/it]
#  48%|████▊     | 350/736 [25:12<27:42,  4.31s/it]
#  48%|████▊     | 351/736 [25:16<27:37,  4.31s/it]
#  48%|████▊     | 352/736 [25:21<27:33,  4.31s/it]
#  48%|████▊     | 353/736 [25:25<27:28,  4.30s/it]
#  48%|████▊     | 354/736 [25:29<27:23,  4.30s/it]
#  48%|████▊     | 355/736 [25:34<27:19,  4.30s/it]
#  48%|████▊     | 356/736 [25:38<27:15,  4.30s/it]
#  49%|████▊     | 357/736 [25:42<27:10,  4.30s/it]
#  49%|████▊     | 358/736 [25:46<27:05,  4.30s/it]
#  49%|████▉     | 359/736 [25:51<27:01,  4.30s/it]
#  49%|████▉     | 360/736 [25:55<26:57,  4.30s/it]
#  49%|████▉     | 361/736 [25:59<26:53,  4.30s/it]
#  49%|████▉     | 362/736 [26:04<26:48,  4.30s/it]
#  49%|████▉     | 363/736 [26:08<26:43,  4.30s/it]
#  49%|████▉     | 364/736 [26:12<26:40,  4.30s/it]
#  50%|████▉     | 365/736 [26:17<26:35,  4.30s/it]
#  50%|████▉     | 366/736 [26:21<26:31,  4.30s/it]
#  50%|████▉     | 367/736 [26:25<26:27,  4.30s/it]
#  50%|█████     | 368/736 [26:29<26:22,  4.30s/it]
#  50%|█████     | 369/736 [26:34<26:18,  4.30s/it]
#  50%|█████     | 370/736 [26:38<26:14,  4.30s/it]
#  50%|█████     | 371/736 [26:42<26:10,  4.30s/it]
#  51%|█████     | 372/736 [26:47<26:06,  4.30s/it]
#  51%|█████     | 373/736 [26:51<26:01,  4.30s/it]
#  51%|█████     | 374/736 [26:55<25:57,  4.30s/it]
#  51%|█████     | 375/736 [27:00<25:53,  4.30s/it]
#  51%|█████     | 376/736 [27:04<25:48,  4.30s/it]
#  51%|█████     | 377/736 [27:08<25:44,  4.30s/it]
#  51%|█████▏    | 378/736 [27:12<25:39,  4.30s/it]
#  51%|█████▏    | 379/736 [27:17<25:35,  4.30s/it]
#  52%|█████▏    | 380/736 [27:21<25:31,  4.30s/it]
#  52%|█████▏    | 381/736 [27:25<25:26,  4.30s/it]
#  52%|█████▏    | 382/736 [27:30<25:22,  4.30s/it]
#  52%|█████▏    | 383/736 [27:34<25:18,  4.30s/it]
#  52%|█████▏    | 384/736 [27:38<25:14,  4.30s/it]
#  52%|█████▏    | 385/736 [27:43<25:10,  4.30s/it]
#  52%|█████▏    | 386/736 [27:47<25:05,  4.30s/it]
#  53%|█████▎    | 387/736 [27:51<25:01,  4.30s/it]
#  53%|█████▎    | 388/736 [27:55<24:57,  4.30s/it]
#  53%|█████▎    | 389/736 [28:00<24:52,  4.30s/it]
#  53%|█████▎    | 390/736 [28:04<24:47,  4.30s/it]
#  53%|█████▎    | 391/736 [28:08<24:44,  4.30s/it]
#  53%|█████▎    | 392/736 [28:13<24:39,  4.30s/it]
#  53%|█████▎    | 393/736 [28:17<24:35,  4.30s/it]
#  54%|█████▎    | 394/736 [28:21<24:31,  4.30s/it]
#  54%|█████▎    | 395/736 [28:26<24:27,  4.30s/it]
#  54%|█████▍    | 396/736 [28:30<24:22,  4.30s/it]
#  54%|█████▍    | 397/736 [28:34<24:18,  4.30s/it]
#  54%|█████▍    | 398/736 [28:38<24:12,  4.30s/it]
#  54%|█████▍    | 399/736 [28:43<24:09,  4.30s/it]
#  54%|█████▍    | 400/736 [28:47<24:04,  4.30s/it]
#  54%|█████▍    | 401/736 [28:51<24:00,  4.30s/it]
#  55%|█████▍    | 402/736 [28:56<23:56,  4.30s/it]
#  55%|█████▍    | 403/736 [29:00<23:52,  4.30s/it]
#  55%|█████▍    | 404/736 [29:04<23:48,  4.30s/it]
#  55%|█████▌    | 405/736 [29:09<23:44,  4.30s/it]
#  55%|█████▌    | 406/736 [29:13<23:40,  4.30s/it]
#  55%|█████▌    | 407/736 [29:17<23:35,  4.30s/it]
#  55%|█████▌    | 408/736 [29:22<23:30,  4.30s/it]
#  56%|█████▌    | 409/736 [29:26<23:26,  4.30s/it]
#  56%|█████▌    | 410/736 [29:30<23:22,  4.30s/it]
#  56%|█████▌    | 411/736 [29:34<23:17,  4.30s/it]
#  56%|█████▌    | 412/736 [29:39<23:13,  4.30s/it]
#  56%|█████▌    | 413/736 [29:43<23:09,  4.30s/it]
#  56%|█████▋    | 414/736 [29:47<23:05,  4.30s/it]
#  56%|█████▋    | 415/736 [29:52<23:00,  4.30s/it]
#  57%|█████▋    | 416/736 [29:56<22:56,  4.30s/it]
#  57%|█████▋    | 417/736 [30:00<22:52,  4.30s/it]
#  57%|█████▋    | 418/736 [30:05<22:48,  4.30s/it]
#  57%|█████▋    | 419/736 [30:09<22:44,  4.31s/it]
#  57%|█████▋    | 420/736 [30:13<22:40,  4.31s/it]
#  57%|█████▋    | 421/736 [30:17<22:37,  4.31s/it]
#  57%|█████▋    | 422/736 [30:22<22:33,  4.31s/it]
#  57%|█████▋    | 423/736 [30:26<22:30,  4.31s/it]
#  58%|█████▊    | 424/736 [30:30<22:26,  4.31s/it]
#  58%|█████▊    | 425/736 [30:35<22:21,  4.31s/it]
#  58%|█████▊    | 426/736 [30:39<22:17,  4.31s/it]
#  58%|█████▊    | 427/736 [30:43<22:13,  4.32s/it]
#  58%|█████▊    | 428/736 [30:48<22:09,  4.32s/it]
#  58%|█████▊    | 429/736 [30:52<22:07,  4.32s/it]
#  58%|█████▊    | 430/736 [30:56<22:02,  4.32s/it]
#  59%|█████▊    | 431/736 [31:01<21:58,  4.32s/it]
#  59%|█████▊    | 432/736 [31:05<21:54,  4.32s/it]
#  59%|█████▉    | 433/736 [31:09<21:49,  4.32s/it]
#  59%|█████▉    | 434/736 [31:14<21:45,  4.32s/it]
#  59%|█████▉    | 435/736 [31:18<21:41,  4.32s/it]
#  59%|█████▉    | 436/736 [31:22<21:37,  4.32s/it]
#  59%|█████▉    | 437/736 [31:27<21:33,  4.32s/it]
#  60%|█████▉    | 438/736 [31:31<21:29,  4.33s/it]
#  60%|█████▉    | 439/736 [31:35<21:25,  4.33s/it]
#  60%|█████▉    | 440/736 [31:40<21:20,  4.33s/it]
#  60%|█████▉    | 441/736 [31:44<21:16,  4.33s/it]
#  60%|██████    | 442/736 [31:48<21:11,  4.32s/it]
#  60%|██████    | 443/736 [31:53<21:07,  4.32s/it]
#  60%|██████    | 444/736 [31:57<21:02,  4.32s/it]
#  60%|██████    | 445/736 [32:01<20:58,  4.32s/it]
#  61%|██████    | 446/736 [32:06<20:53,  4.32s/it]
#  61%|██████    | 447/736 [32:10<20:49,  4.32s/it]
#  61%|██████    | 448/736 [32:14<20:45,  4.32s/it]
#  61%|██████    | 449/736 [32:19<20:40,  4.32s/it]
#  61%|██████    | 450/736 [32:23<20:36,  4.32s/it]
#  61%|██████▏   | 451/736 [32:27<20:32,  4.32s/it]
#  61%|██████▏   | 452/736 [32:31<20:28,  4.32s/it]
#  62%|██████▏   | 453/736 [32:36<20:24,  4.33s/it]
#  62%|██████▏   | 454/736 [32:40<20:19,  4.33s/it]
#  62%|██████▏   | 455/736 [32:44<20:15,  4.33s/it]
#  62%|██████▏   | 456/736 [32:49<20:12,  4.33s/it]
#  62%|██████▏   | 457/736 [32:53<20:07,  4.33s/it]
#  62%|██████▏   | 458/736 [32:57<20:03,  4.33s/it]
#  62%|██████▏   | 459/736 [33:02<20:00,  4.33s/it]
#  62%|██████▎   | 460/736 [33:06<19:56,  4.34s/it]
#  63%|██████▎   | 461/736 [33:10<19:52,  4.34s/it]
#  63%|██████▎   | 462/736 [33:15<19:47,  4.33s/it]
#  63%|██████▎   | 463/736 [33:19<19:42,  4.33s/it]
#  63%|██████▎   | 464/736 [33:23<19:36,  4.33s/it]
#  63%|██████▎   | 465/736 [33:28<19:32,  4.33s/it]
#  63%|██████▎   | 466/736 [33:32<19:27,  4.33s/it]
#  63%|██████▎   | 467/736 [33:36<19:23,  4.33s/it]
#  64%|██████▎   | 468/736 [33:41<19:19,  4.33s/it]
#  64%|██████▎   | 469/736 [33:45<19:15,  4.33s/it]
#  64%|██████▍   | 470/736 [33:49<19:10,  4.33s/it]
#  64%|██████▍   | 471/736 [33:54<19:06,  4.33s/it]
#  64%|██████▍   | 472/736 [33:58<19:01,  4.32s/it]
#  64%|██████▍   | 473/736 [34:02<18:57,  4.32s/it]
#  64%|██████▍   | 474/736 [34:07<18:52,  4.32s/it]
#  65%|██████▍   | 475/736 [34:11<18:48,  4.32s/it]
#  65%|██████▍   | 476/736 [34:15<18:43,  4.32s/it]
#  65%|██████▍   | 477/736 [34:20<18:39,  4.32s/it]
#  65%|██████▍   | 478/736 [34:24<18:34,  4.32s/it]
#  65%|██████▌   | 479/736 [34:28<18:30,  4.32s/it]
#  65%|██████▌   | 480/736 [34:33<18:26,  4.32s/it]
#  65%|██████▌   | 481/736 [34:37<18:22,  4.32s/it]
#  65%|██████▌   | 482/736 [34:41<18:16,  4.32s/it]
#  66%|██████▌   | 483/736 [34:46<18:11,  4.32s/it]
#  66%|██████▌   | 484/736 [34:50<18:07,  4.32s/it]
#  66%|██████▌   | 485/736 [34:54<18:02,  4.31s/it]
#  66%|██████▌   | 486/736 [34:59<17:58,  4.31s/it]
#  66%|██████▌   | 487/736 [35:03<17:53,  4.31s/it]
#  66%|██████▋   | 488/736 [35:07<17:49,  4.31s/it]
#  66%|██████▋   | 489/736 [35:11<17:44,  4.31s/it]
#  67%|██████▋   | 490/736 [35:16<17:40,  4.31s/it]
#  67%|██████▋   | 491/736 [35:20<17:35,  4.31s/it]
#  67%|██████▋   | 492/736 [35:24<17:30,  4.31s/it]
#  67%|██████▋   | 493/736 [35:29<17:26,  4.31s/it]
#  67%|██████▋   | 494/736 [35:33<17:21,  4.30s/it]
#  67%|██████▋   | 495/736 [35:37<17:17,  4.31s/it]
#  67%|██████▋   | 496/736 [35:42<17:13,  4.31s/it]
#  68%|██████▊   | 497/736 [35:46<17:08,  4.30s/it]
#  68%|██████▊   | 498/736 [35:50<17:04,  4.30s/it]
#  68%|██████▊   | 499/736 [35:54<16:59,  4.30s/it]
#  68%|██████▊   | 500/736 [35:59<16:56,  4.31s/it]
#  68%|██████▊   | 501/736 [36:03<16:51,  4.30s/it]
#  68%|██████▊   | 502/736 [36:07<16:47,  4.31s/it]
#  68%|██████▊   | 503/736 [36:12<16:43,  4.31s/it]
#  68%|██████▊   | 504/736 [36:16<16:38,  4.30s/it]
#  69%|██████▊   | 505/736 [36:20<16:35,  4.31s/it]
#  69%|██████▉   | 506/736 [36:25<16:30,  4.31s/it]
#  69%|██████▉   | 507/736 [36:29<16:26,  4.31s/it]
#  69%|██████▉   | 508/736 [36:33<16:21,  4.31s/it]
#  69%|██████▉   | 509/736 [36:38<16:17,  4.31s/it]
#  69%|██████▉   | 510/736 [36:42<16:12,  4.30s/it]
#  69%|██████▉   | 511/736 [36:46<16:08,  4.30s/it]
#  70%|██████▉   | 512/736 [36:50<16:03,  4.30s/it]
#  70%|██████▉   | 513/736 [36:55<15:59,  4.30s/it]
#  70%|██████▉   | 514/736 [36:59<15:55,  4.30s/it]
#  70%|██████▉   | 515/736 [37:03<15:50,  4.30s/it]
#  70%|███████   | 516/736 [37:08<15:46,  4.30s/it]
#  70%|███████   | 517/736 [37:12<15:42,  4.30s/it]
#  70%|███████   | 518/736 [37:16<15:37,  4.30s/it]
#  71%|███████   | 519/736 [37:21<15:33,  4.30s/it]
#  71%|███████   | 520/736 [37:25<15:28,  4.30s/it]
#  71%|███████   | 521/736 [37:29<15:24,  4.30s/it]
#  71%|███████   | 522/736 [37:33<15:20,  4.30s/it]
#  71%|███████   | 523/736 [37:38<15:16,  4.30s/it]
#  71%|███████   | 524/736 [37:42<15:11,  4.30s/it]
#  71%|███████▏  | 525/736 [37:46<15:07,  4.30s/it]
#  71%|███████▏  | 526/736 [37:51<15:02,  4.30s/it]
#  72%|███████▏  | 527/736 [37:55<14:58,  4.30s/it]
#  72%|███████▏  | 528/736 [37:59<14:54,  4.30s/it]
#  72%|███████▏  | 529/736 [38:04<14:50,  4.30s/it]
#  72%|███████▏  | 530/736 [38:08<14:45,  4.30s/it]
#  72%|███████▏  | 531/736 [38:12<14:41,  4.30s/it]
#  72%|███████▏  | 532/736 [38:16<14:37,  4.30s/it]
#  72%|███████▏  | 533/736 [38:21<14:32,  4.30s/it]
#  73%|███████▎  | 534/736 [38:25<14:28,  4.30s/it]
#  73%|███████▎  | 535/736 [38:29<14:24,  4.30s/it]
#  73%|███████▎  | 536/736 [38:34<14:20,  4.30s/it]
#  73%|███████▎  | 537/736 [38:38<14:15,  4.30s/it]
#  73%|███████▎  | 538/736 [38:42<14:11,  4.30s/it]
#  73%|███████▎  | 539/736 [38:47<14:07,  4.30s/it]
#  73%|███████▎  | 540/736 [38:51<14:03,  4.30s/it]
#  74%|███████▎  | 541/736 [38:55<13:58,  4.30s/it]
#  74%|███████▎  | 542/736 [38:59<13:54,  4.30s/it]
#  74%|███████▍  | 543/736 [39:04<13:50,  4.30s/it]
#  74%|███████▍  | 544/736 [39:08<13:45,  4.30s/it]
#  74%|███████▍  | 545/736 [39:12<13:41,  4.30s/it]
#  74%|███████▍  | 546/736 [39:17<13:36,  4.30s/it]
#  74%|███████▍  | 547/736 [39:21<13:32,  4.30s/it]
#  74%|███████▍  | 548/736 [39:25<13:28,  4.30s/it]
#  75%|███████▍  | 549/736 [39:30<13:24,  4.30s/it]
#  75%|███████▍  | 550/736 [39:34<13:20,  4.30s/it]
#  75%|███████▍  | 551/736 [39:38<13:16,  4.30s/it]
#  75%|███████▌  | 552/736 [39:43<13:11,  4.30s/it]
#  75%|███████▌  | 553/736 [39:47<13:07,  4.30s/it]
#  75%|███████▌  | 554/736 [39:51<13:02,  4.30s/it]
#  75%|███████▌  | 555/736 [39:55<12:58,  4.30s/it]
#  76%|███████▌  | 556/736 [40:00<12:54,  4.30s/it]
#  76%|███████▌  | 557/736 [40:04<12:49,  4.30s/it]
#  76%|███████▌  | 558/736 [40:08<12:45,  4.30s/it]
#  76%|███████▌  | 559/736 [40:13<12:41,  4.30s/it]
#  76%|███████▌  | 560/736 [40:17<12:37,  4.30s/it]
#  76%|███████▌  | 561/736 [40:21<12:32,  4.30s/it]
#  76%|███████▋  | 562/736 [40:26<12:28,  4.30s/it]
#  76%|███████▋  | 563/736 [40:30<12:24,  4.30s/it]
#  77%|███████▋  | 564/736 [40:34<12:20,  4.30s/it]
#  77%|███████▋  | 565/736 [40:38<12:16,  4.31s/it]
#  77%|███████▋  | 566/736 [40:43<12:11,  4.30s/it]
#  77%|███████▋  | 567/736 [40:47<12:07,  4.31s/it]
#  77%|███████▋  | 568/736 [40:51<12:03,  4.31s/it]
#  77%|███████▋  | 569/736 [40:56<11:59,  4.31s/it]
#  77%|███████▋  | 570/736 [41:00<11:55,  4.31s/it]
#  78%|███████▊  | 571/736 [41:04<11:50,  4.31s/it]
#  78%|███████▊  | 572/736 [41:09<11:45,  4.30s/it]
#  78%|███████▊  | 573/736 [41:13<11:41,  4.30s/it]
#  78%|███████▊  | 574/736 [41:17<11:37,  4.30s/it]
#  78%|███████▊  | 575/736 [41:21<11:32,  4.30s/it]
#  78%|███████▊  | 576/736 [41:26<11:28,  4.30s/it]
#  78%|███████▊  | 577/736 [41:30<11:24,  4.30s/it]
#  79%|███████▊  | 578/736 [41:34<11:20,  4.30s/it]
#  79%|███████▊  | 579/736 [41:39<11:15,  4.30s/it]
#  79%|███████▉  | 580/736 [41:43<11:11,  4.30s/it]
#  79%|███████▉  | 581/736 [41:47<11:06,  4.30s/it]
#  79%|███████▉  | 582/736 [41:52<11:02,  4.30s/it]
#  79%|███████▉  | 583/736 [41:56<10:58,  4.30s/it]
#  79%|███████▉  | 584/736 [42:00<10:53,  4.30s/it]
#  79%|███████▉  | 585/736 [42:05<10:49,  4.30s/it]
#  80%|███████▉  | 586/736 [42:09<10:44,  4.30s/it]
#  80%|███████▉  | 587/736 [42:13<10:40,  4.30s/it]
#  80%|███████▉  | 588/736 [42:17<10:36,  4.30s/it]
#  80%|████████  | 589/736 [42:22<10:32,  4.30s/it]
#  80%|████████  | 590/736 [42:26<10:27,  4.30s/it]
#  80%|████████  | 591/736 [42:30<10:23,  4.30s/it]
#  80%|████████  | 592/736 [42:35<10:19,  4.30s/it]
#  81%|████████  | 593/736 [42:39<10:14,  4.30s/it]
#  81%|████████  | 594/736 [42:43<10:10,  4.30s/it]
#  81%|████████  | 595/736 [42:47<10:05,  4.30s/it]
#  81%|████████  | 596/736 [42:52<10:01,  4.30s/it]
#  81%|████████  | 597/736 [42:56<09:56,  4.29s/it]
#  81%|████████▏ | 598/736 [43:00<09:52,  4.30s/it]
#  81%|████████▏ | 599/736 [43:05<09:48,  4.30s/it]
#  82%|████████▏ | 600/736 [43:09<09:44,  4.30s/it]
#  82%|████████▏ | 601/736 [43:13<09:39,  4.30s/it]
#  82%|████████▏ | 602/736 [43:18<09:35,  4.30s/it]
#  82%|████████▏ | 603/736 [43:22<09:31,  4.29s/it]
#  82%|████████▏ | 604/736 [43:26<09:26,  4.29s/it]
#  82%|████████▏ | 605/736 [43:30<09:22,  4.29s/it]
#  82%|████████▏ | 606/736 [43:35<09:17,  4.29s/it]
#  82%|████████▏ | 607/736 [43:39<09:13,  4.29s/it]
#  83%|████████▎ | 608/736 [43:43<09:09,  4.29s/it]
#  83%|████████▎ | 609/736 [43:48<09:04,  4.29s/it]
#  83%|████████▎ | 610/736 [43:52<09:00,  4.29s/it]
#  83%|████████▎ | 611/736 [43:56<08:55,  4.29s/it]
#  83%|████████▎ | 612/736 [44:00<08:51,  4.29s/it]
#  83%|████████▎ | 613/736 [44:05<08:47,  4.29s/it]
#  83%|████████▎ | 614/736 [44:09<08:43,  4.29s/it]
#  84%|████████▎ | 615/736 [44:13<08:38,  4.29s/it]
#  84%|████████▎ | 616/736 [44:18<08:34,  4.28s/it]
#  84%|████████▍ | 617/736 [44:22<08:29,  4.28s/it]
#  84%|████████▍ | 618/736 [44:26<08:25,  4.29s/it]
#  84%|████████▍ | 619/736 [44:30<08:21,  4.29s/it]
#  84%|████████▍ | 620/736 [44:35<08:17,  4.29s/it]
#  84%|████████▍ | 621/736 [44:39<08:13,  4.29s/it]
#  85%|████████▍ | 622/736 [44:43<08:08,  4.29s/it]
#  85%|████████▍ | 623/736 [44:48<08:04,  4.29s/it]
#  85%|████████▍ | 624/736 [44:52<08:00,  4.29s/it]
#  85%|████████▍ | 625/736 [44:56<07:56,  4.29s/it]
#  85%|████████▌ | 626/736 [45:00<07:51,  4.29s/it]
#  85%|████████▌ | 627/736 [45:05<07:47,  4.29s/it]
#  85%|████████▌ | 628/736 [45:09<07:43,  4.29s/it]
#  85%|████████▌ | 629/736 [45:13<07:39,  4.30s/it]
#  86%|████████▌ | 630/736 [45:18<07:35,  4.30s/it]
#  86%|████████▌ | 631/736 [45:22<07:31,  4.30s/it]
#  86%|████████▌ | 632/736 [45:26<07:27,  4.30s/it]
#  86%|████████▌ | 633/736 [45:31<07:23,  4.30s/it]
#  86%|████████▌ | 634/736 [45:35<07:18,  4.30s/it]
#  86%|████████▋ | 635/736 [45:39<07:14,  4.30s/it]
#  86%|████████▋ | 636/736 [45:43<07:10,  4.30s/it]
#  87%|████████▋ | 637/736 [45:48<07:06,  4.30s/it]
#  87%|████████▋ | 638/736 [45:52<07:01,  4.30s/it]
#  87%|████████▋ | 639/736 [45:56<06:57,  4.30s/it]
#  87%|████████▋ | 640/736 [46:01<06:53,  4.30s/it]
#  87%|████████▋ | 641/736 [46:05<06:49,  4.31s/it]
#  87%|████████▋ | 642/736 [46:09<06:44,  4.31s/it]
#  87%|████████▋ | 643/736 [46:14<06:40,  4.31s/it]
#  88%|████████▊ | 644/736 [46:18<06:36,  4.31s/it]
#  88%|████████▊ | 645/736 [46:22<06:31,  4.31s/it]
#  88%|████████▊ | 646/736 [46:27<06:27,  4.31s/it]
#  88%|████████▊ | 647/736 [46:31<06:23,  4.31s/it]
#  88%|████████▊ | 648/736 [46:35<06:19,  4.31s/it]
#  88%|████████▊ | 649/736 [46:39<06:14,  4.31s/it]
#  88%|████████▊ | 650/736 [46:44<06:10,  4.31s/it]
#  88%|████████▊ | 651/736 [46:48<06:06,  4.31s/it]
#  89%|████████▊ | 652/736 [46:52<06:02,  4.31s/it]
#  89%|████████▊ | 653/736 [46:57<05:58,  4.31s/it]
#  89%|████████▉ | 654/736 [47:01<05:53,  4.31s/it]
#  89%|████████▉ | 655/736 [47:05<05:49,  4.31s/it]
#  89%|████████▉ | 656/736 [47:10<05:44,  4.31s/it]
#  89%|████████▉ | 657/736 [47:14<05:40,  4.31s/it]
#  89%|████████▉ | 658/736 [47:18<05:36,  4.31s/it]
#  90%|████████▉ | 659/736 [47:23<05:31,  4.31s/it]
#  90%|████████▉ | 660/736 [47:27<05:27,  4.31s/it]
#  90%|████████▉ | 661/736 [47:31<05:23,  4.31s/it]
#  90%|████████▉ | 662/736 [47:36<05:19,  4.31s/it]
#  90%|█████████ | 663/736 [47:40<05:15,  4.32s/it]
#  90%|█████████ | 664/736 [47:44<05:10,  4.31s/it]
#  90%|█████████ | 665/736 [47:48<05:06,  4.31s/it]
#  90%|█████████ | 666/736 [47:53<05:02,  4.32s/it]
#  91%|█████████ | 667/736 [47:57<04:57,  4.32s/it]
#  91%|█████████ | 668/736 [48:01<04:53,  4.32s/it]
#  91%|█████████ | 669/736 [48:06<04:48,  4.31s/it]
#  91%|█████████ | 670/736 [48:10<04:44,  4.31s/it]
#  91%|█████████ | 671/736 [48:14<04:40,  4.31s/it]
#  91%|█████████▏| 672/736 [48:19<04:35,  4.31s/it]
#  91%|█████████▏| 673/736 [48:23<04:31,  4.31s/it]
#  92%|█████████▏| 674/736 [48:27<04:27,  4.31s/it]
#  92%|█████████▏| 675/736 [48:32<04:23,  4.31s/it]
#  92%|█████████▏| 676/736 [48:36<04:18,  4.31s/it]
#  92%|█████████▏| 677/736 [48:40<04:14,  4.31s/it]
#  92%|█████████▏| 678/736 [48:45<04:10,  4.31s/it]
#  92%|█████████▏| 679/736 [48:49<04:05,  4.31s/it]
#  92%|█████████▏| 680/736 [48:53<04:01,  4.31s/it]
#  93%|█████████▎| 681/736 [48:57<03:57,  4.31s/it]
#  93%|█████████▎| 682/736 [49:02<03:53,  4.32s/it]
#  93%|█████████▎| 683/736 [49:06<03:48,  4.32s/it]
#  93%|█████████▎| 684/736 [49:10<03:44,  4.32s/it]
#  93%|█████████▎| 685/736 [49:15<03:40,  4.32s/it]
#  93%|█████████▎| 686/736 [49:19<03:36,  4.32s/it]
#  93%|█████████▎| 687/736 [49:23<03:31,  4.32s/it]
#  93%|█████████▎| 688/736 [49:28<03:27,  4.32s/it]
#  94%|█████████▎| 689/736 [49:32<03:23,  4.32s/it]
#  94%|█████████▍| 690/736 [49:36<03:18,  4.32s/it]
#  94%|█████████▍| 691/736 [49:41<03:14,  4.32s/it]
#  94%|█████████▍| 692/736 [49:45<03:10,  4.32s/it]
#  94%|█████████▍| 693/736 [49:49<03:05,  4.32s/it]
#  94%|█████████▍| 694/736 [49:54<03:01,  4.32s/it]
#  94%|█████████▍| 695/736 [49:58<02:57,  4.32s/it]
#  95%|█████████▍| 696/736 [50:02<02:52,  4.32s/it]
#  95%|█████████▍| 697/736 [50:07<02:48,  4.32s/it]
#  95%|█████████▍| 698/736 [50:11<02:44,  4.32s/it]
#  95%|█████████▍| 699/736 [50:15<02:39,  4.32s/it]
#  95%|█████████▌| 700/736 [50:20<02:35,  4.32s/it]
#  95%|█████████▌| 701/736 [50:24<02:31,  4.32s/it]
#  95%|█████████▌| 702/736 [50:28<02:27,  4.33s/it]
#  96%|█████████▌| 703/736 [50:33<02:22,  4.33s/it]
#  96%|█████████▌| 704/736 [50:37<02:18,  4.34s/it]
#  96%|█████████▌| 705/736 [50:41<02:14,  4.34s/it]
#  96%|█████████▌| 706/736 [50:46<02:10,  4.35s/it]
#  96%|█████████▌| 707/736 [50:50<02:06,  4.35s/it]
#  96%|█████████▌| 708/736 [50:54<02:01,  4.34s/it]
#  96%|█████████▋| 709/736 [50:59<01:57,  4.34s/it]
#  96%|█████████▋| 710/736 [51:03<01:52,  4.34s/it]
#  97%|█████████▋| 711/736 [51:07<01:48,  4.33s/it]
#  97%|█████████▋| 712/736 [51:12<01:43,  4.33s/it]
#  97%|█████████▋| 713/736 [51:16<01:39,  4.32s/it]
#  97%|█████████▋| 714/736 [51:20<01:34,  4.32s/it]
#  97%|█████████▋| 715/736 [51:25<01:30,  4.31s/it]
#  97%|█████████▋| 716/736 [51:29<01:25,  4.30s/it]
#  97%|█████████▋| 717/736 [51:33<01:21,  4.29s/it]
#  98%|█████████▊| 718/736 [51:37<01:17,  4.28s/it]
#  98%|█████████▊| 719/736 [51:42<01:12,  4.28s/it]
#  98%|█████████▊| 720/736 [51:46<01:08,  4.28s/it]
#  98%|█████████▊| 721/736 [51:50<01:04,  4.28s/it]
#  98%|█████████▊| 722/736 [51:55<01:00,  4.29s/it]
#  98%|█████████▊| 723/736 [51:59<00:55,  4.30s/it]
#  98%|█████████▊| 724/736 [52:03<00:51,  4.31s/it]
#  99%|█████████▊| 725/736 [52:08<00:47,  4.32s/it]
#  99%|█████████▊| 726/736 [52:12<00:43,  4.33s/it]
#  99%|█████████▉| 727/736 [52:16<00:38,  4.33s/it]
#  99%|█████████▉| 728/736 [52:21<00:34,  4.34s/it]
#  99%|█████████▉| 729/736 [52:25<00:30,  4.34s/it]
#  99%|█████████▉| 730/736 [52:29<00:26,  4.33s/it]
#  99%|█████████▉| 731/736 [52:34<00:21,  4.33s/it]
#  99%|█████████▉| 732/736 [52:38<00:17,  4.33s/it]
# 100%|█████████▉| 733/736 [52:42<00:12,  4.33s/it]
# 100%|█████████▉| 734/736 [52:47<00:08,  4.33s/it]
# 100%|█████████▉| 735/736 [52:51<00:04,  4.32s/it]
# 100%|██████████| 736/736 [52:52<00:00,  4.31s/it]
# 7266
# ('Бразилия – Колумбия. Неймар покинул поле на носилках. Нападающий сборной Бразилии Неймар получил травму в матче 1/4 финала чемпионата мира-2014. '
#  'Форвард «Барселоны» покинул поле на носилках после удара коленом в спину от колумбийского футболиста. Вместо него на поле вышел Энрике. Бразилия – '
#  'Колумбия – 2:1. Как это было\n'
#  'Рамос не хуже разных неймаров раскидал соперников на бегу финтами и вырулил атаку своей сборной на финиш 4 в 4! Однако пас в офсайд запортил все '
#  'дело. Паулиньо, уходя с поля, показывает, кого не надо забывать держать. Эрнанес вместо него. Суньига с разбега коленом в крестец - приличный '
#  'рестлеровский прием выводит Неймара из игры. Энрике вместо Неймара, который на носилках транспортируется прямиком в раздевалку. Блокируют удар '
#  'Бакки. Всей командой пошли колумбийцы в атаку. Родригес играет в тело, возможно, своего будущего одноклубника. Несладко пришлось Марсело получить '
#  'плечом в грудь от Хамеса. +5 минут. Если будут играть так, как сейчас, то еще +30, пожалуйста, серию пенальти и переигровку. Снуют в чужой '
#  'штрафной колумбийцы-убийцы! Рамос едва не вывалился на убойную с точеным ударом! Йепес на последнем рубеже обороны - не последнем рубеже обороны '
#  'бразильцев. В нужный момент он подставит ногу куда надо. Удар головой! Мимо. Максимум шанс-полтора еще будет у команды Пекермана. Оспина в '
#  'штрафной бразильцев, а на Рамосе виснут сразу трое, не давая пробить головой. Все, пентакампеоны выигрывают мяч на чужой половине. Финальный '
#  'свисток! 2:1 - Бразилия усилиями двух центрбеков "ПСЖ" вышибает пеструю Колумбию и продолжает пусть к домашнему триумфу.  Спасибо, что были с '
#  'нами! Большое человеческое спасибо. И доброй ночи.')
# 1
#
#
# 6719
# ('Калинин удален до конца матча со Швецией. Защитник сборной России Дмитрий Калинин был удален до конца матча группового этапа ЧМ-2012 против '
#  'Швеции. В третьем периоде в борьбе на пятачке россиянин разбил лицо форварду шведов Юхану Франзену. Калинин получил штраф 5+20. У Франзена на лице '
#  'выступила кровь, и он отправился в раздевалку, где ему оказали медицинскую помощь. Россия – Швеция. Онлайн\n'
#  'Расстрельный щелчок Никулина с ползоны! Фаст начал выручать... Шведские болельщики покидают арену. ДЕНИСОВ - 7:3!!! Передача Малкина, щелчок с '
#  'линии круга вбрасывания (метров с семи) - Фаст не удержал шайбу. Не его матч... Сирена застает россиян в атаке... Удивительная по сюжету игра! '
#  'Заслуженное "Молодцы - молодцы" в конце! Евгений Малкин окончательно запугал всех своим мастерством на чемпионате: 5 (3+2) очка в игре. Впечатляет '
#  'и Александр Попов: в связке с Малкиным ему удалось наработать сегодня 4 (1+3) очка. А вот Виктор Фаст будет вспоминать игру без энтузиазма - '
#  'думаю, одна из самых печальных в его карьере. Да и Юхан Франзен вряд ли доволен тем, как повел себя во втором периоде. Возможно, его агрессия '
#  'против Емелина и Малкина и стала главной причиной шведского поражения. Сборная России становится безоговорочным лидером группы B: 15 очков в 5 '
#  'матчах. Впереди еще встречи с Чехией и Италией. Евгений Малкин вышел в лидеры списка бомбардиров - привычная картина в этом сезоне: 12 (6+6) очков '
#  'в 5 матчах. Всего вам доброго, спасибо за участие в онлайне и до новых встреч на sports.ru! 7:3 - Россия отстокгольмила Швецию в матче, который, '
#  'как будто, ничего и не значил. И это при счете по броскам 36-46.')
# 0
#
#
# 3224
# ('«Рейнджерс» – «Ванкувер». Биекса подрался с Бойлом. Защитник «Ванкувера» Кевин Биекса во время матча регулярного чемпионата с «Рейнджерс» подрался '
#  'с форвардом Брайаном Бойлом. Хоккеисты померялись силами в концовке встречи, на 60-й минуте. Отметим, что Биекса после драки забрал шлем соперника '
#  'и пнул его на лед.\n'
#  'ДАНИЭЛЬ СЕДИН - 5:2!!! 10-й гол в чемпионате! Добил шайбу с пятака после наброса Эдлера и помощи Кеслера. Зукарелло! Сотрясает штангу броском '
#  'метров с шести! У Ричардсона был шанс возродить надежды гостей, но с пятачка трудно было забить ему. Бойл против Биексы! Явно обозлен Биекса, ему '
#  'нужно на ком-то "оторваться". Когда Биекса в ярости, он Ковальчука напоминает. Выбрал большого, но не бойцовского по сути своей парня. Оттаскал, '
#  'конечно, но выглядело все это безобразно. Как мелкое хулиганство на улице. 5:2 - хет-трик Крайдера поставил "Ванкувер" Тортореллы на колени. '
#  'Крайдер, Нэш и Тэлбот названы лучшими в матче. Для "Рейнджерс" это два важных очка, означающие продолжение активной битвы за плей-офф. "Ванкувер" '
#  'в ближайшее время может лишиться и 9-го места на Западе. Команду может обойти "Нэшвилл", а в перспективе - и "Даллас". Итог по броскам в створ '
#  '24-37. Надо запомнить фамилию Кэм Тэлбот. Возможно, это новая вратарская "звезда" в НХЛ. С текущей статистикой и другой информацией о командах на '
#  'нашем сайте вы можете ознакомиться здесь: http://www.sports.ru/tags/1046609.html ("Рейнджерс"), http://www.sports.ru/tags/1046656.html '
#  '("Ванкувер").\r\n'
#  'Данные уже обновлены! Большое вам спасибо за чтение. Всего доброго и до новых встреч на наших онлайнах!')
# 0
#
#
# 56
# ('Чехия и Россия установили рекорд по количеству голов в матчах за 3-е место. Чехия и Россия, забросив на двоих 11 шайб в матче за 3-е место '
#  'чемпионата мира-2011, установили рекорд игр за бронзу по количеству голов на мировых первенствах и Олимпийских играх, сообщает официальный сайт '
#  'ИИХФ. Напомним, матч завершился победой чехов 7:4. Отметим также, что эта игра стала первой для российской сборной, в которой она пропустила 7 '
#  'шайб в рамках чемпионата мира .\n'
#  'Кулемин с ближней штанги пытается добавлять наброс от борта Атюшова. Гадамчик решил тайм-аут взять. Возможно, просто дает отдохнуть лишний раз '
#  'своим защитникам. Катают чехи шайбу по окружности площадки, а наши им только помогают в этом... Наши ворота опустели. ПЛЕКАНЕЦ!!!! 7:4! Возможно, '
#  'лучший игрок чехов на данный момент, обыграв двух наших игроков на правом краю, забивает с метра в пустые. Ягр и Червенка ассистенты, если что. '
#  'Радулов справа кистями в дальний угол целит - не-а. МАРЕК! Слева с шести метров почти без помех атакует, выше ворот! Артюхин на последних секундах '
#  'чуть не подрался. Но и не хотел, похоже. Да и что тут дракой докажешь... 7:4 в пользу Чехии, и у нашей команды четвертое место! Счет по броскам в '
#  'створ 28-43. Поздравляем сборную Чехии с заслуженным третьим местом! Наша команда заканчивает турнир с худшим результатом за последние пять лет. '
#  'Лучшими игроками матча признаны Роман Червенка и Илья Ковальчук. Четыре победы и пять поражений в девяти матчах. Это счастье, что с таким '
#  'результатом мы занимаем четвертое место. Всего вам доброго, никогда не унывайте, и до новых встреч на хоккее на текстовых онлайнах Sports.ru! До '
#  'встречи на финале через два часа!')
# 1
#
#
# 4683
# ('«Металлург» Нк – «Динамо» Минск. Гаврус получил травму во втором периоде и покинул лед. Нападающий минского «Динамо» Артур Гаврус получил травму в '
#  'матче регулярного чемпионата КХЛ против новокузнецкого «Металлурга» (2:2, второй перерыв). Белорусский хоккеист неудачно врезался в борт в '
#  'концовке второго периода и смог покинуть лед только с помощью работников «Скорой помощи». О характере травмы Гавруса не сообщается. В раздевалке с '
#  'Гаврусом работают врачи «Скорой» и доктор команды.\n'
#  'Половина овертайма на исходе. Подавляющее преимущество белорусской команды! Вот первый полумомент у ворот Лаланда в овертайме - ничего опасного '
#  'нет. Кольцов перспективно входил в зону, но потерял шайбу спустя несколько десятков секунд Лаланд. Бэйлен бросил в дальнюю девятку - Кареев без '
#  'особых проблем ловушкой поймал шайбу. Щехура бросил с близкой дистанции - снова Кареев непробиваем в этом эпизоде! Калюжный хорошо перевел шайбу '
#  'на Гундерссона - едва-едва не вырвал американец победу для "Динамо" за пару секунд до сирены. Буллиты нас ждут. Что ж, в отличие от основного '
#  'времени, минчане в овертайме полностью доминировали. Но перед серией буллитов это неважно: это ведь лоторея. Мелешко начинает серию бросков. Свой '
#  'коронный буллит исполнял Мелешко! Все правильно сделал, но попал в клюшку Кареева. Стоа против Лаланда - на скорости Райан исполнял буллит, но '
#  'неудачно. Выше ворот. Щехура тоже не пробил голкипера "Металлурга". Стеной он стал в ворота! Фэйрчайлд без особой техники бросил - не возникло '
#  'проблем. Калюжный тоже не блещет - в домик пытался пробить. Но Кареев на месте. Капризов тоже Лаланда не переиграл. 0:0 после трех попыток! Стоа '
#  'снова попробовал бросить, но Лаланд без проблем отбил шайбу. Степанов!!! гол!!! Отлично сыграл Андрей и протолкнул шайбу между ног Кареева. Все! '
#  'Побеждает "Динамо" сегодня.')
# 0
#
#
# 861
# ('ЦСКА – СКА. Ковальчук забросил первую шайбу в Кубке Гагарина. Нападающий СКА Илья Ковальчук в четвертом матче серии 1/8 финала Кубка Гагарина с '
#  'ЦСКА открыл счет своим голам в Кубке Гагарина. Хоккеист отличился на 54-й минуте, сделав счет 3:4. Это первое очко Ковальчука в текущем плей-офф. '
#  'Статистику хоккеиста смотрите здесь . ЦСКА – СКА. Онлайн\n'
#  'Сапрыкин имел очередной шанс на добивании, и в очередной раз остался ни с чем. гол? Питер забивает, вернее - заталкивает шайбу в ворота после '
#  'броска Ковальчука, но шайба может быть не засчитана! ПОНИКАРОВСКИЙ - 4:5!!! 1-й гол в плей-офф! В падении проталкивает шайбу за линию, успев '
#  'первым на отскок от броска с левого края от Ковальчука, заработавшего, по идее, свой второй результативный балл сегодня. Да и Каблуков передачу '
#  'заслужил. В НХЛ бы ее точно засчитали. 4:5 и 0-4 в серии - победив во втором овертайме подряд, СКА из Санкт-Петербурга выходит во второй раунд '
#  'Кубка Гагарина. Возможно, судьи были не идеальны, а ЦСКА где-то не повезло. Но в целом исход серии справедлив и пред-СКА-зуем. Итог по броскам в '
#  'створ 45-43. Глэсс играл неплохо, но все-таки в ключевые моменты не выручил свою команду. Думаю, ЦСКА продолжит поиски "своего" вратаря, но уже в '
#  'межсезонье. Не забудьте, что сегодня ночью у нас онлайн встречи "Питтсбург" - "Вашингтон" с участием Малкина, Овечкина, Кузнецова и Орлова. '
#  'Большое вам спасибо за чтение. Всего доброго и до новых встреч на наших онлайнах!')
# 0
#
#
# 3408
# ...
#  'игра, что называется, на три результата. Команды стремятся вырвать победу, забывая об обороне. Баштуш! Бил головой в прыжке из вратарской после '
#  'подачи Торбинского - чуть выше цели! "Арсенал" прижался к воротам. Лучше синица в руке? Хозяева отодвинули игру в центр поля, стало легче им '
#  'дышать. +3 минуты еще. Туляки явно не спешат вводить мяч из аута - ничья их устраивает. Ах, какие хитрецы! Чуть не убежал в контре Вотинов! Конец '
#  'матча, 1:1. Хотя свисток прозвучал за несколько секунд до завершения встречи, когда "Арсенал" устремлялся в очередную контратаку. Хозяева '
#  'недовольны и предъявляют претензии Матюнину. В целом исход игры закономерен. "Арсенал" здорово прибавил во 2-м тайме, хотя будь Бухаров '
#  'эффективнее, "Ростов" мог уехать и с 3 очками. Соперники прервали свои проигрышные серии, и то хлеб. По итоговой статистике тоже все ровно: '
#  'владение 41%–59%, удары (в створ) 11(5)–11(5), угловые 6-7, фолы 17–13, предупреждения 2–3. Очередной матч РФПЛ подошел к концу, но самое '
#  'интересное еще впереди. Спасибо за внимание, до новых встреч, болейте только футболом!')
# 0
#
#
# 7680
# ('«Локомотив» – «Спартак». В стартовом составе красно-белых впервые с 2000 года вышли 4 российских защитника. В составе «Спартака» в сегодняшнем '
#  'матча 23-го тура чемпионата России против «Локомотива» впервые за долгое время в защите играют четыре российских футболиста. Оборонительную линию '
#  'красно-белых составили Сергей Брызгалов, Сергей Паршивлюк, Евгений Макеев и Дмитрий Комбаров. В последний раз «Спартак» выходил на поле с '
#  'российской четверкой защитников 15 апреля 2000 года – тогда в матче с «Крыльями Советов» (2:1) сыграли Дмитрий Хлестов, Евгений Бушманов, '
#  'Александр Щеголев и Юрий Ковтун. Sports.ru ведет онлайн-трансляцию матча «Локомотив» – «Спартак».\n'
#  '"Локомотив" сегодня был неплох и больше заслужил победы, но, на мой взгляд, Леонид Кучук запоздал с заменами - нужно было освежить игру раньше. '
#  'Леонид Кучук во флэш-интервью говорит, что это был матч лигочемпионского уровня - одна ошибка могла решить его исход. Обе команды сыграли очень '
#  'цепко в средней зоне, что по мнению Кучука говорит о классе команд. А поздние замены? Говорит никто не устал и игра не требовала усиления.  '
#  'Статистика матча : владение мячом 53-47%, удары по воротам 9-6, из них в створ 3-3, угловые 2-2, нарушения 19-19, предупреждения 2-4. Равенство '
#  'почти во всем! И все-таки с турнирной точки зрения "Локомотив" сегодня потерял два очка. "Зенит" теперь отстает всего на очко и через месяц их '
#  'ждет очная встреча в Черкизово. Правда, никто не может точно сказать с каким очковым багажом команды подойдут к этой игре. Особенно "Зенит" На '
#  'этом все на сегодня. Впереди еще три матча чемпионата России сегодня - ближайший в Томске, а завершит вечер краснодарское дерби! Не пропустите! Мы '
#  'будем на каждой из этих игр. Спасибо за внимание, и до новых встреч в эфире. С вами был Василий Рябинко и дружная команда Sports.ru-Tribuna.com.')
# 0
#
#
# 4401
# ('«Чикаго» – «Вашингтон». Овечкин забил первый гол в сезоне. Нападающий «Вашингтона» Александр Овечкин, сравняв счет в матче с «Чикаго» (1:1, 1-й '
#  'период), забросил первую шайбу в новом регулярном чемпионате НХЛ. 28-летний игрок сборной России отличился на 10-й минуте, реализовав большинство, '
#  'после передач Никласа Бэкстрема и Михаила Грабовского. Sports.ru провел онлайн-трансляцию матча «Чикаго» – «Вашингтон» .\n'
#  'Лучшими игроками встречи названы Саад, Грабовский и Одуя. Сомнительный выбор, на мой взгляд - Холтби за 5-6 суперспасений точно должен быть в '
#  'списке. А великолепная игра защитника Ялмарссона? Но, увы, "тройки" формируются в основном за голы, очки и решающие шайбы. Александр Овечкин был '
#  'более чем заметен - гол, пас, 9 бросков в створ и полезность -2. Шведская пара защитников "Чикаго" Одуя - Ялмарссон была великолепна: на двоих - '
#  'победный гол, 1+2, полезность +8 (!!!) и 7 блок-шотов. А вот еще одна показательная статистика, свидетельствующая о классе игры команд без шайбы: '
#  'на 9 перехватов у "Чикаго" приходится 1 - у "Кэпиталс". Да один Дацюк за матч совершает больше перехватов, чем весь "Вашингтон"! Команда Оутса '
#  'практически не мешала "Чикаго" играть в свою игру. Всего вам доброго, спасибо за чтение и до новых встреч на наших онлайнах! Не забудьте создать '
#  'свою фэнтези-команду НХЛ на нашем сайте. Как это сделать? Читайте форум "Фэнтези НХЛ" (http://www.sports.ru/tribuna/forums/fantasynhl/).')
# 0
#
#
# 6313
# ('Натхо сделал дубль в матче с «Аланией». Полузащитник «Рубина» Бибарс Натхо в матче второго тура чемпионата России-2012/13 против «Алании» забил '
#  'свои второй и третий голы в сезоне. На 18-й минуте израильтянин реализовал пенальти, назначенный за фол против Кристиана Ансальди, а на 48-й '
#  'минуте отличился с игры. Отметим, что в матче прошлого тура с «Краснодаром» (1:2) Натхо также забил единственный мяч казанского клуба. «Рубин» – '
#  '«Алания». Онлайн\n'
#  'Вместо Хубулова выходит Турсунов. Пенальти! На этот раз в ворота "Рубина"! В руку Боккетти попал мяч после безобидного навеса с фланга. Забивает '
#  'Неко, столь же легко, как Натхо в первом тайме. 2:1. Неко закрепляет успех - в центре поля грубо играет против Натхо. "Алания", похоже, поверила в '
#  'свои силы. Вот теперь уже никуда не спешит "Рубин". Некуда больше спешить. Приличный штрафной зарабатывает "Алания". До ворот метров 23-25. '
#  'Классный удар удался Кардосо! Над перекладиной пролетел мяч. Рязанцев здорово пробил после хорошего прострела Дядюна - Хомич выручил "Аланию", '
#  'угловой. "Алания" никак не может выгнать соперника со своей половины поля. Штрафной для "Рубина". + 3 минуты. Карадениз выполнил навес точно в '
#  'руки Хомичу. В ответной атаке Пришкин не сумел прострелить на партнера - и снова на месте вратарь. И это все! 3:1, победа за "Рубином". гол! 3:1! '
#  'Дядюн! Гости ошиблись с созданием искусственного офсайда, Рязанцев проскочил по флангу и выкатил мяч в центр, а Владимир легко переиграл вратаря. '
#  'Итоговая статистика: удары (в створ): 8 (6) - 4 (0), угловые: 3-3, фолы: 23- 27. Поздравляем "Рубин" с первой победой! Спасибо, что были с нами, '
#  'друзья, до новых встреч! Например, на матче "Спартак" - "Волга" =)')
# 0
#
#
# 7153
# ('«Кубань» – «Спартак». Ромуло получил травму. Полузащитник «Спартака» Ромуло получил травму в матче 12-го тура чемпионата России против «Кубани» (в '
#  'данный момент счет 1:0). На 35-й минуте встречи вместо бразильца на поле вышел хавбек Денис Глушаков. Напомним, что Sports.ru ведет '
#  'онлайн-трансляцию матча «Кубань» – «Спартак» .\n'
#  'Последняя замена у хозяев: Хубулов вместо Игнатьева. Бальде подставляет голову после подачи корнера! Мяч просвистел в метре от штанги! У "Кубани" '
#  'все-таки больше желания вырвать победу. Эберт закручивал в ворота прямо с углового - Беленов с трудом кулаками выбивает мяч! И последняя замена у '
#  'гостей: Хурадо вместо Яковлева. Еще один могучий выстрел Попова! Мяч попадает в руку спартаковца, который находился в своей штрафной, но скорее '
#  'попадает, чем игра рукой! 4 минуты добавлено. Додавит "Кубань"? Ребров вытаскивает из верхнего угла сумасшедший удар Хубулова!  И впрямь такое '
#  'ощущение, что у южан на одного игрока больше. Ребров не торопится вводить мяч в игру. "Спартак" перевел игру на половину хозяев, но до моментов '
#  'дело не дошло. Все, боевая ничья 3:3! Но с горьким послевкусием для "Кубани". Мы увидели кучу голов, спасибо командам за результативный футбол! '
#  '"Кубань" догоняет идущего третьим "Краснодар", а красно-белые сравниваются по очкам с "Рубином", "Локомотивом" и "Динамо". Правда, у казанцев и '
#  'бело-голубых по одной игре в запасе. Итоговая статистика: владение 52%–48%, удары (в створ) 17(8)–6(4), угловые 4-5, фолы 20–18, предупреждения '
#  '3–2. Очередной матч РФПЛ подошел к концу, но самое интересное еще впереди. Спасибо за внимание, до новых встреч, болейте только футболом!')
# 0
#
#
# 9469
# ('«Краснодар» — «Терек». Крицюк дебютировал за «быков». Вратарь «Краснодара» Станислав Крицюк вышел в стартовом составе на четвертьфинальный матч '
#  'Кубка России против «Терека» (0:0, дополнительное время). Таким образом, 25-летний россиянин, арендованный у «Браги» с правом выкупа, дебютировал '
#  'за краснодарский клуб. Sports.ru проводит текстовую онлайн-трансляцию этого матча.\n'
#  'Мы продолжаем. Команды по-честному пытаются вырвать победу - мяч по-прежнему очень быстро перемещается от штрафной до штрафной. Торбинский в '
#  'который раз в этом матче навесил с левого фланга в штрафную на Мамаева и Павел ударом с 13 метров головой пробил в нескольких метрах от штанги. '
#  'Смолов сделал заброс на Перейру к линии штрафной "Терека", но отлично играющий сегодня Городов вышел из ворот и головой выбил мяч за лицевую! '
#  'Тренеры тем временем уже советуются с помощниками, кому бить пенальти. Рахимов шепнул что-то Ледяхову. гол! И все-таки! После подачи углового '
#  'капитан "Краснодара" Гранквист перевисел в воздухе Семенова и ударом головой с линии вратарской ввинтил мяч в сетку! Замена тут же у "Терека": '
#  'вместо Грозава вышел Рыбус. А Лебеденко вышел вместо Пириса. Грозненцы из последних сил грузят мяч в штрафную соперника, но краснодарцы легко '
#  'отбиваются. 1 минуту компенсировал арбитр. Финиш! "Краснодар" выходит в полуфинал! Игра была равной, все катилось к серии пенальти, но удачный '
#  'вояж в штрафную капитана хозяев Гранквиста лишил зрителей серии пенальти. "Краснодар" тем самым реабилитировался за вылет из еврокубков, а "Терек" '
#  'был очень хорош, как для старта сезона. Всем спасибо, пока!')
# 0
#
#
# 323
# ('«Вашингтон» – «Торонто». Кузнецов отметился голевой передачей. Форвард «Вашингтона» Евгений Кузнецов в матче регулярного чемпионата с «Торонто» '
#  '(4:2) отметился голевой передачей. Россиянин выступил одним из ассистентов Джоэла Уорда, когда тот забрасывал третью шайбу. В четырех матчах '
#  'регулярного чемпионата на счету Кузнецова 4 (0+4) очка. Подробную статистику смотрите здесь . «Вашингтон» – «Торонто» – 4:2. Как это было\n'
#  'БРАУЭР - 4:2!!! Дубль и 20-й гол в чемпионате! По-бильярдному, от бортика, из своей зоны - мастерски. В пустые ворота, само собой. Бэкстрем '
#  'сопровождал шайбу, но вгонять ее с линии не пришлось. 4:2 - "Вашингтон" перед архисложной серией против лучших команд Запада сумел немного поднять '
#  'себе настроение. Матч получился интересным из-за того, что долгое время держался скользкий счет. А во второй половине встречи блестяще заиграли '
#  'вратари. Итог по броскам в створ 33-29. Если смотреть второстепенные статистические показатели, то и по ним примерное равенство. Только в силовой '
#  'игре хозяева были чуть старательнее. Александр Овечкин выдал очередной матч со знаком "минус". Теперь по рейтингу полезности у него только один '
#  '"конкурент" - Наиль Якупов (-33). У Ови -31. Евгений Кузнецов имеет на счету 4 голевые передачи в 4 матчах, но 3 из них назвать эпическими никак '
#  'нельзя. Зато Пеннер выдал сегодня чудо-пас в стиле лучших мастеров этого дела. Только поразиться порой можно, что выдают те, кого обычно называют '
#  '"дуболомами" или "бройлерами". Наш матч-центр - настоящий кладезь информации, где, в том числе, самые актуальные сведения о хоккейных матчах дня: '
#  'http://www.sports.ru/stat/hockey/center/ Большое вам спасибо за чтение. Всего доброго и до новых встреч на наших онлайнах!')
# 0
#
#
# 8791
# ('НХЛ. Раст забросил 6-ю шайбу в плей-офф, побив рекорд «Питтсбурга» среди новичков. Форвард «Питтсбурга» Брайан Раст в стартовом финальном матче '
#  'Кубка Стэнли против «Сан-Хосе» (2:1, идет 2-й период) открыл счет. Это 6-й гол американца в текущем плей-офф, и он установил новый рекорд '
#  '«Пингвинс» среди новичков. Всего в 18 играх нынешнего розыгрыша на счету Раста 9 (6+3) очков. В 55 матчах регулярного чемпионата НХЛ за карьеру он '
#  'забросил 5 шайб.\n'
#  '"Сан Хосе" не помогает и замена вратаря. Плюс для "пингвинов" сейчас - возможность спокойно бросать в сторону ворот "акул" без опасности получить '
#  'вбрасывание. 3:2 - "Питтсбург" вырывает победу в концовке первого матча финальной серии! Вновь успех команде Салливана обеспечило чудодейственное '
#  'звено Кессел - Бонино - Хагелин. Но и тройки Кросби и Малкина также отметились шайбами!  Первый раунд противостояния за "пингвинами". Они были '
#  'лучше в первом и третьем периодах, намного чаще грузили Джонса бросками (41-26), и сохраняют потенциал на игре в большинстве, забросив все три '
#  'шайбы в равных составах. Новички "пингвинов" из фарм-клубов продолжают приятно удивлять. Бонино, Шери и Марло названы лучшими игроками матча. '
#  'Удивительно, как Марло попал в тройку - на его счету весьма грязный хит на Расте. На мой взгляд, место Марло в тройке лучших более подошло бы '
#  'защитнику Летангу - 27:48 на льду, полезность +2, 4 броска в створ, 2 силовых приема, пас на победный гол. Евгений Малкин сыграл не самый свой '
#  'звездный матч, но находится, как говорится, в положительном тренде - почти 16 минут игрового времени, полезность +1, 2 броска в створ, 5 '
#  'выигранных вбрасываний. Большое спасибо за чтение! До новых встреч на хоккейных онлайнах.')
# 0
#
#
# 8838
# ('Акинфеев увеличил антирекорд Лиги чемпионов, пропустив в 32-м матче подряд. Нападающий «Вольфсбурга» Андре Шуррле забил гол в матче 5-го тура '
#  'группового этапа Лиги чемпионов с ЦСКА . Таким образом, вратарь армейцев Игорь Акинфеев увеличил антирекорд турнира, пропустив в 32-м матче '
#  'подряд. Напомним, что Акинфеев установил этот антирекорд, пропустив в 17-м подряд матче Лиги чемпионов в домашней игре с «Викторией» из Пльзени '
#  '(3:2) в позапрошлом сезоне. Бывший голкипер ПСВ Роналд Ватеррес пропускал в 16 матчах Лиги чемпионов подряд, экс-вратарь «Панатинаикоса» и '
#  '«Олимпиакоса» Антонис Никополидис – в 15. На счету Шэя Гивена, игравшего в Лиге чемпионов за «Ньюкасл», серия из 14 матчей. Антирекорд Акинфеева '
#  'учитывает только матчи в групповой стадии и плей-офф ЛЧ, пропущенные им мячи в играх квалификации турнира считаются отдельно и не идут в общий '
#  'зачет. Последний сухой матч Акинфеева в Лиге чемпионов состоялся 9 лет назад в матче с «Арсеналом» на «Эмирейтс» – 1 ноября 2006 года. Подробную '
#  'статистику\n'
#  'Миланов очень робко шел на мяч, но поздним подкатом все же вышел на позицию для кросса! Однако его навес перехвачен кипером. Юнг вместо Крузе у '
#  'немцев. Продолжает ЦСКА стучаться в штрафную "волков". Но до ударов по воротам дело никак не доходит. Тошич пасует на ход Мусе! Обработка была '
#  'хороша, но мяч опускался вертикально - и удрать от двоих соперников не удалось!  Бендтнер вместо Доста. Легенда атаки против легенды в воротах. '
#  'гол! ШЮРРЛЕ! Дубль! Открылся на периметр и шлепнул по встречному - в противоход Акинфееву! 0:2!  Панченко вместо Дзагоева. Бендтнер бьет в обвод '
#  'Акинфеева и попадает в ШТАНГУ!! Натхо полчает горчичник за то, что наступил на пятку сопернику. Думбия палит с разворота! Не доходит мяч даже до '
#  'Бенальо. Все. Проиграл ЦСКА. Штанга Тошича, автогол Акинфеева и финальный аккорд от Шюррле - 0:2. Лига чемпионов на этом для армейцев закончена.  '
#  'Это была славная охота. Но опять безрезультатная. Момент Думбия с "МЮ", удар в штангу Тошича здесь и суперрекорд Акинфеева - армейцам есть, за что '
#  'обижаться на удачу.  Спасибо, что были с нами! Спишемся на "Юве" - "Ман Сити"!')
# 0
#  75%|███████▌  | 3/4 [3:08:53<1:02:34, 3754.12s/it]
#     <div>
#
#       <progress value='108' max='108' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [108/108 03:12, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.488300</td>
#       <td>0.430454</td>
#       <td>0.862921</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.171800</td>
#       <td>0.121726</td>
#       <td>0.974155</td>
#     </tr>
#   </tbody>
# </table><p>
# 100%|██████████| 4/4 [3:12:08<00:00, 2882.00s/it]

# %%
m = AutoModelForSequenceClassification.from_pretrained("/content/checkpoint-108")
trainer = BaalTransformersTrainer(
    model=m,
    args=training_args,
    train_dataset=active_set,
    eval_dataset=test_set,
    tokenizer=None,
    compute_metrics=compute_metrics
)
output = trainer.evaluate()
output
# Out:
#     <div>
#
#       <progress value='24' max='24' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [24/24 00:09]
#     </div>
# {'eval_loss': 0.11491850763559341,
#  'eval_f1': 0.9763779527559056,
#  'eval_runtime': 9.8966,
#  'eval_samples_per_second': 37.791,
#  'eval_steps_per_second': 2.425}

# %%
# !cp -r "/content/checkpoint-108" "/content/drive/MyDrive/RuSportSum/bald"
